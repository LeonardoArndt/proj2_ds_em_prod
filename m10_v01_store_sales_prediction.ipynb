# %% [markdown]
# # 0.0 Imports

# %% [markdown]
# ## 0.0. Imports

# %%
import pandas as pd
import inflection
import math
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from IPython.display import Image
from IPython.core.display import HTML
import datetime
sns.set(rc = {'figure.figsize':(15,8)})
from tabulate import tabulate
from matplotlib import gridspec
from scipy import stats as ss
import random
#para ignorar os alertas futuros
import warnings
warnings.filterwarnings('ignore')
import pickle
import requests

#feacture selection
from boruta import BorutaPy
from sklearn.preprocessing import RobustScaler, MinMaxScaler, LabelEncoder

#ml modeling LINEAR
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb

# %% [markdown]
# ## 0.1. Helper Functions

# %%
# configurações para facilitar o uso do jupyternotebook
#def jupyter_settings():
#    %matplotlib inline
#    %pylab inline
#    plt.style.use( 'bmh' )
#    plt.rcParams['figure.figsize'] = [25, 12]
#    plt.rcParams['font.size'] = 24
#    display( HTML( '<style>.container { width:100% !important; }</style>') )
#    pd.options.display.max_columns = None
#    pd.options.display.max_rows = None
#    pd.set_option( 'display.expand_frame_repr', False )
#    sns.set()

# %%
#jupyter_settings()

# %%
display( HTML( '<style>.container { width:100% !important; }</style>') )
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# usado no cap 6 - Feature Selection
def cramer_v( x, y ):
    cm = pd.crosstab( x, y ).values
    n = cm.sum()
    r, k = cm.shape
    chi2 = ss.chi2_contingency( cm )[0]
    chi2corr = max( 0, chi2 - (k-1)*(r-1)/(n-1) )
    kcorr = k - (k-1)**2/(n-1)
    rcorr = r - (r-1)**2/(n-1)
    return np.sqrt( (chi2corr/n) / ( min( kcorr-1, rcorr-1 ) ) )

# %%
# usado no cap 7 - ML modelling
def mean_absolute_percentage_error(y, yhat):
    return np.mean(np.abs((y - yhat)/y))


def ml_error(model_name, y, yhat):
    mae = mean_absolute_error(y, yhat)
    mape = mean_absolute_percentage_error(y, yhat)
    rmse = np.sqrt(mean_squared_error(y, yhat))
    
    return pd.DataFrame({'Model Name': model_name,
                         'MAE': mae,
                         'MAPE': mape,
                         'RMSE': rmse}, index = [0])

# %%
#usada no crossvalidation
def crossvalidation(x_training, kfold, model_name, model, verbose = False):
    mae_list = []
    mape_list = []
    rmse_list = []
    for k in reversed(range(1,kfold+1)):
        #inicio do validation
        validation_start_date = x_training['date'].max() - datetime.timedelta(days = k*6*7)
        #final do valitation é o final do dataset
        validation_end_date = x_training['date'].max() - datetime.timedelta(days = ((k-1)*6*7))
        #final do treino é menor que o início do validation
        training = x_training[x_training['date'] < validation_start_date]
        validation = x_training[(x_training['date'] >= validation_start_date) & ( x_training['date'] <= validation_end_date)]
        
        if verbose:
            #acompanhamento
            print(k)
            print(validation_start_date)
            print(validation_end_date)
        
        #selecionando
        xvalidation = validation.drop(['date', 'sales'], axis = 1)
        yvalidation = validation['sales']
        
        #selecionando
        xtraining = training.drop(['date', 'sales'], axis = 1)
        ytraining = training['sales']
        
        #model
        m = model.fit(xtraining, ytraining)
        
        #prediction
        yhat = m.predict(xvalidation)
        
        #performance
        m_result = ml_error(model_name, np.expm1(yvalidation), np.expm1(yhat))
        
        mae_list.append(m_result['MAE'])
        mape_list.append(m_result['MAPE'])
        rmse_list.append(m_result['RMSE'])
        
    return pd.DataFrame({'Model_name': model_name,
                         'MAE_CV': np.round(np.mean(mae_list),2).astype(str) + ' +/- ' + np.round(np.std(mae_list),2).astype(str),
                         'MAPE_CV': np.round(np.mean(mape_list),2).astype(str) + ' +/- ' + np.round(np.std(mape_list),2).astype(str),
                         'RMSE_CV': np.round(np.mean(rmse_list),2).astype(str) + ' +/- ' + np.round(np.std(rmse_list),2).astype(str)}, index = [0])

# %% [markdown]
# ## 0.2 Loading data

# %%
df_sales_raw = pd.read_csv('train.csv', low_memory = False)
df_store_raw = pd.read_csv('store.csv', low_memory = False)

# %%
df_raw = pd.merge(df_sales_raw, df_store_raw, how = 'left', on = 'Store')
df_raw
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                  0              1         c          a               1270.0
# 1                  0              1         a          a                570.0
# 2                  0              1         a          a              14130.0
# 3                  0              1         c          c                620.0
# 4                  0              1         a          a              29910.0
# ...              ...            ...       ...        ...                  ...
# 1017204            a              1         a          a               1900.0
# 1017205            a              1         c          c               1880.0
# 1017206            a              1         a          c               9260.0
# 1017207            a              1         a          c                870.0
# 1017208            a              1         d          c               5350.0
#
#          CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                              9.0                    2008.0       0
# 1                             11.0                    2007.0       1
# 2                             12.0                    2006.0       1
# 3                              9.0                    2009.0       0
# 4                              4.0                    2015.0       0
# ...                            ...                       ...     ...
# 1017204                        6.0                    2014.0       1
# 1017205                        4.0                    2006.0       0
# 1017206                        NaN                       NaN       0
# 1017207                        NaN                       NaN       0
# 1017208                        NaN                       NaN       1
#
#          Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 0                    NaN              NaN               NaN
# 1                   13.0           2010.0   Jan,Apr,Jul,Oct
# 2                   14.0           2011.0   Jan,Apr,Jul,Oct
# 3                    NaN              NaN               NaN
# 4                    NaN              NaN               NaN
# ...                  ...              ...               ...
# 1017204             31.0           2013.0   Jan,Apr,Jul,Oct
# 1017205              NaN              NaN               NaN
# 1017206              NaN              NaN               NaN
# 1017207              NaN              NaN               NaN
# 1017208             22.0           2012.0  Mar,Jun,Sept,Dec
#
# [1017209 rows x 18 columns]

# %% [markdown]
# # 1.0 Data Description

# %%
df1 = df_raw.copy()

# %% [markdown]
# ## 1.1 Rename columns

# %%
df1.columns
cols_old = ['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
       'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
       'CompetitionDistance', 'CompetitionOpenSinceMonth',
       'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
       'Promo2SinceYear', 'PromoInterval']

# %%
snakecase = lambda x : inflection.underscore(x)
cols_new = list(map(snakecase, cols_old))
df1.columns = cols_new

# %%
df1
# Out:
#          store  day_of_week        date  sales  customers  open  promo  \
# 0            1            5  2015-07-31   5263        555     1      1
# 1            2            5  2015-07-31   6064        625     1      1
# 2            3            5  2015-07-31   8314        821     1      1
# 3            4            5  2015-07-31  13995       1498     1      1
# 4            5            5  2015-07-31   4822        559     1      1
# ...        ...          ...         ...    ...        ...   ...    ...
# 1017204   1111            2  2013-01-01      0          0     0      0
# 1017205   1112            2  2013-01-01      0          0     0      0
# 1017206   1113            2  2013-01-01      0          0     0      0
# 1017207   1114            2  2013-01-01      0          0     0      0
# 1017208   1115            2  2013-01-01      0          0     0      0
#
#         state_holiday  school_holiday store_type assortment  \
# 0                   0               1          c          a
# 1                   0               1          a          a
# 2                   0               1          a          a
# 3                   0               1          c          c
# 4                   0               1          a          a
# ...               ...             ...        ...        ...
# 1017204             a               1          a          a
# 1017205             a               1          c          c
# 1017206             a               1          a          c
# 1017207             a               1          a          c
# 1017208             a               1          d          c
#
#          competition_distance  competition_open_since_month  \
# 0                      1270.0                           9.0
# 1                       570.0                          11.0
# 2                     14130.0                          12.0
# 3                       620.0                           9.0
# 4                     29910.0                           4.0
# ...                       ...                           ...
# 1017204                1900.0                           6.0
# 1017205                1880.0                           4.0
# 1017206                9260.0                           NaN
# 1017207                 870.0                           NaN
# 1017208                5350.0                           NaN
#
#          competition_open_since_year  promo2  promo2_since_week  \
# 0                             2008.0       0                NaN
# 1                             2007.0       1               13.0
# 2                             2006.0       1               14.0
# 3                             2009.0       0                NaN
# 4                             2015.0       0                NaN
# ...                              ...     ...                ...
# 1017204                       2014.0       1               31.0
# 1017205                       2006.0       0                NaN
# 1017206                          NaN       0                NaN
# 1017207                          NaN       0                NaN
# 1017208                          NaN       1               22.0
#
#          promo2_since_year    promo_interval
# 0                      NaN               NaN
# 1                   2010.0   Jan,Apr,Jul,Oct
# 2                   2011.0   Jan,Apr,Jul,Oct
# 3                      NaN               NaN
# 4                      NaN               NaN
# ...                    ...               ...
# 1017204             2013.0   Jan,Apr,Jul,Oct
# 1017205                NaN               NaN
# 1017206                NaN               NaN
# 1017207                NaN               NaN
# 1017208             2012.0  Mar,Jun,Sept,Dec
#
# [1017209 rows x 18 columns]

# %% [markdown]
# ## 1.2 Data dimensions

# %%
print('Number of rows {}'.format(df1.shape[0]))
print('Number of cols {}'.format(df1.shape[1]))
# Out:
# Number of rows 1017209
# Number of cols 18

# %% [markdown]
# ## 1.3 Data types

# %%
df1['date'] = pd.to_datetime(df1['date'])
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# dtype: object

# %% [markdown]
# ## 1.4 Check NA

# %%
df1.isna().sum()
# Out:
# store                                0
# day_of_week                          0
# date                                 0
# sales                                0
# customers                            0
# open                                 0
# promo                                0
# state_holiday                        0
# school_holiday                       0
# store_type                           0
# assortment                           0
# competition_distance              2642
# competition_open_since_month    323348
# competition_open_since_year     323348
# promo2                               0
# promo2_since_week               508031
# promo2_since_year               508031
# promo_interval                  508031
# dtype: int64

# %% [markdown]
# ## 1.5 Fillout NA

# %%
#competition_distance
# se não tem competidor, podemos supor que está muito longe
df1['competition_distance'] = df1['competition_distance'].apply(lambda x : 200000.0 if math.isnan(x) else x)

#competition_open_since_month 
# se for na, copio a data da venda, pois pode possuir competidor mas a data de abertura não está explicita
df1['competition_open_since_month'] = df1.apply(lambda x : x['date'].month if math.isnan(x['competition_open_since_month']) else x['competition_open_since_month'], axis = 1)


#competition_open_since_year
# se for na, copio a data da loja, pois pode possuir competidor mas a data de abertura não está explicita
df1['competition_open_since_year'] = df1.apply(lambda x : x['date'].year if math.isnan(x['competition_open_since_year']) else x['competition_open_since_year'], axis = 1)


#promo2_since_week   
#a loja decidiu não parcitipar da segunda promoção, então substituo pela valor da data que ela começou para saber a partir de quando ela caiu fora
df1['promo2_since_week'] = df1.apply(lambda x : x['date'].week if math.isnan(x['promo2_since_week']) else x['promo2_since_week'], axis = 1)


#promo2_since_year
#a loja decidiu não parcitipar da segunda promoção, então substituo pela valor da data que ela começou para saber a partir de quando ela caiu fora
df1['promo2_since_year'] = df1.apply(lambda x : x['date'].year if math.isnan(x['promo2_since_year']) else x['promo2_since_year'], axis = 1)


#promo_interval
#para identifica os meses que a promo2 tava ativa
month_map = {1: 'Jan', 2: 'Fev', 3: 'Mar', 4: 'Abr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Jun', 9: 'Aug', 10: 'Sep', 11: 'Nov', 12: 'Dez'}
df1['promo_interval'].fillna(0, inplace = True)
df1['month_map'] = df1['date'].dt.month.map(month_map)
df1['is_promo'] = df1[['promo_interval', 'month_map']].apply(lambda x: 0 if x['promo_interval'] == 0 else 1 if x['month_map'] in x['promo_interval'].split(',') else 0, axis = 1)

# %%
df1.head(5)
# Out:
#    store  day_of_week       date  sales  customers  open  promo state_holiday  \
# 0      1            5 2015-07-31   5263        555     1      1             0
# 1      2            5 2015-07-31   6064        625     1      1             0
# 2      3            5 2015-07-31   8314        821     1      1             0
# 3      4            5 2015-07-31  13995       1498     1      1             0
# 4      5            5 2015-07-31   4822        559     1      1             0
#
#    school_holiday store_type assortment  competition_distance  \
# 0               1          c          a                1270.0
# 1               1          a          a                 570.0
# 2               1          a          a               14130.0
# 3               1          c          c                 620.0
# 4               1          a          a               29910.0
#
#    competition_open_since_month  competition_open_since_year  promo2  \
# 0                           9.0                       2008.0       0
# 1                          11.0                       2007.0       1
# 2                          12.0                       2006.0       1
# 3                           9.0                       2009.0       0
# 4                           4.0                       2015.0       0
#
#    promo2_since_week  promo2_since_year   promo_interval month_map  is_promo
# 0               31.0             2015.0                0       Jul         0
# 1               13.0             2010.0  Jan,Apr,Jul,Oct       Jul         1
# 2               14.0             2011.0  Jan,Apr,Jul,Oct       Jul         1
# 3               31.0             2015.0                0       Jul         0
# 4               31.0             2015.0                0       Jul         0

# %% [markdown]
# ## 1.6 Change Types

# %%
df1['competition_open_since_month'] = df1['competition_open_since_month'].astype('int64')
df1['competition_open_since_year'] = df1['competition_open_since_year'].astype('int64')

df1['promo2_since_week'] = df1['promo2_since_week'].astype('int64')
df1['promo2_since_year'] = df1['promo2_since_year'].astype('int64')

# %%
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month             int64
# competition_open_since_year              int64
# promo2                                   int64
# promo2_since_week                        int64
# promo2_since_year                        int64
# promo_interval                          object
# month_map                               object
# is_promo                                 int64
# dtype: object

# %% [markdown]
# ## 1.7 Descriptive Statistical

# %% [markdown]
# ## 1.7.1 Numerical

# %%
num_atributes = df1.select_dtypes(include = ['int64', 'float64'])
cat_atributes = df1.select_dtypes(exclude = ['int64', 'float64', 'datetime64[ns]'])

# %%
#central tendenxy - mean, median
ct1 = pd.DataFrame(num_atributes.apply(np.mean))
ct2 = pd.DataFrame(num_atributes.apply(np.median))

#dispersion - std, min, max, range, skew, kurtosis
d1 = pd.DataFrame(num_atributes.apply(np.std))
d2 = pd.DataFrame(num_atributes.apply(min))
d3 = pd.DataFrame(num_atributes.apply(max))
d4 = pd.DataFrame(num_atributes.apply(lambda x : x.max() - x.min()))
d5 = pd.DataFrame(num_atributes.apply(lambda x : x.skew()))
d6 = pd.DataFrame(num_atributes.apply(lambda x : x.kurtosis()))

#concatenate
m = pd.concat([d2, d3, d4, ct1, ct2, d1, d5, d6], axis = 1).reset_index()
m.columns = ['atributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']

# %%
sns.distplot(df1['competition_distance'])
# Out:
# <AxesSubplot:xlabel='competition_distance', ylabel='Density'>

# %% [markdown]
# ## 1.7.2 Category

# %%
cat_atributes.apply(lambda x : x.unique().shape[0])
# Out:
# state_holiday      4
# store_type         4
# assortment         3
# promo_interval     4
# month_map         11
# dtype: int64

# %%
aux1 = df1[(df1['state_holiday'] != '0') & (df1['sales'] > 0)]
plt.subplot(1,3,1)
sns.boxplot(x = 'state_holiday', y = 'sales', data = aux1)

plt.subplot(1,3,2)
sns.boxplot(x = 'store_type', y = 'sales', data = aux1)

plt.subplot(1,3,3)
sns.boxplot(x = 'assortment', y = 'sales', data = aux1)
# Out:
# <AxesSubplot:xlabel='assortment', ylabel='sales'>

# %% [markdown]
# # 2.0 Feature Engineering

# %%
df2 = df1.copy()

# %% [markdown]
# ## 2.1 Mapmind

# %%
Image('img\mapmind.png')

# %% [markdown]
# ## 2.2 Lista de Hipóteses

# %% [markdown]
# 2.2. Criacao das Hipoteses
#
# 2.2.1. Hipoteses Loja
# 1. Lojas com número maior de funcionários deveriam vender mais.
# 2. Lojas com maior capacidade de estoque deveriam vender mais.
# 3. Lojas com maior porte deveriam vender mais.
# 4. Lojas com maior sortimentos deveriam vender mais.
# 5. Lojas com competidores mais próximos deveriam vender menos.
# 6. Lojas com competidores à mais tempo deveriam vendem mais.
#
# 2.2.2. Hipoteses Produto
# 1. Lojas que investem mais em Marketing deveriam vender mais.
# 2. Lojas com maior exposição de produto deveriam vender mais.
# 3. Lojas com produtos com preço menor deveriam vender mais.
# 5. Lojas com promoções mais agressivas ( descontos maiores ), deveriam vender mais.
# 6. Lojas com promoções ativas por mais tempo deveriam vender mais.
# 7. Lojas com mais dias de promoção deveriam vender mais.
# 8. Lojas com mais promoções consecutivas deveriam vender mais.
#
# 2.2.3. Hipoteses Tempo
# 1. Lojas abertas durante o feriado de Natal deveriam vender mais.
# 2. Lojas deveriam vender mais ao longo dos anos.
# 3. Lojas deveriam vender mais no segundo semestre do ano.
# 4. Lojas deveriam vender mais depois do dia 10 de cada mês.
# 5. Lojas deveriam vender menos aos finais de semana.
# 6. Lojas deveriam vender menos durante os feriados escolares.
#
# 2.3. Lista Final de Hipóteses
# 1. Lojas com maior sortimentos deveriam vender mais.
# 2. Lojas com competidores mais próximos deveriam vender menos.
# 3. Lojas com competidores à mais tempo deveriam vendem mais.
# 4. Lojas com promoções ativas por mais tempo deveriam vender mais.
# 5. Lojas com mais dias de promoção deveriam vender mais.
# 7. Lojas com mais promoções consecutivas deveriam vender mais.
# 8. Lojas abertas durante o feriado de Natal deveriam vender mais.
# 9. Lojas deveriam vender mais ao longo dos anos.
# 10. Lojas deveriam vender mais no segundo semestre do ano.
# 11. Lojas deveriam vender mais depois do dia 10 de cada mês.
# 12. Lojas deveriam vender menos aos finais de semana.
# 13. Lojas deveriam vender menos durante os feriados escolares.

# %% [markdown]
# ## 2.3 Features

# %%
#year
df2['year'] = df2['date'].dt.year

#month
df2['month'] = df2['date'].dt.month

#day
df2['day'] = df2['date'].dt.day

#week of year
df2['week_of_year'] = df2['date'].dt.weekofyear

#year week
df2['year_week'] = df2['date'].dt.strftime('%Y-%W')

#competition since month
#juntei o ano com o mês, com isso subtrai com a data, dividi por 30 para deixar em mês, e isolei esse resultado com ox.days
df2['competition_since'] = df2.apply( lambda x : datetime.datetime(year=x['competition_open_since_year'], month=x['competition_open_since_month'],day=1 ), axis=1 )
df2['competition_time_month'] = ( ( df2['date'] - df2['competition_since'] )/30).apply( lambda x: x.days ).astype( int )

#promo since week
#juntei o ano e a semana do ano como string da promoção, apliquei strptime para adicionar dia e transformar em data, subtrai por 7 para pegar o início da semana, depois dividi por sete na subtração para tirar isolar o resultado com o x.days
df2['promo_since'] = df2['promo2_since_year'].astype( str ) + '-' + df2['promo2_since_week'].astype( str )
df2['promo_since'] = df2['promo_since'].apply( lambda x: datetime.datetime.strptime( x + '-1', '%Y-%W-%w' ) - datetime.timedelta( days=7 ) )
df2['promo_time_week'] = ( ( df2['date'] - df2['promo_since'] )/7 ).apply(lambda x: x.days ).astype( int )

#assortment
df2['assortment'] = df2['assortment'].apply( lambda x: 'basic' if x == 'a' else 'extra' if x == 'b' else 'extended' )

#state holiday
df2['state_holiday'] = df2['state_holiday'].apply( lambda x: 'public_holiday' if x == 'a' else 'easter_holiday' if x == 'b' else 'christmas' if x == 'c' else 'regular_day' )

# %% [markdown]
# # 3.0 Variable filterers

# %%
df3 = df2.copy()

# %% [markdown]
# ## 3.1 Filtragem das linhas

# %%
#quando a loja ta fechada não tem venda
df3 = df3[(df3['open'] != 0) & (df3['sales'] > 0)]

# %% [markdown]
# ## 3.2 Filtragem das colunas

# %%
#não saberei quantos clientes terão na loja para ajudar na prediçã no futuro
df3 = df3.drop(['customers', 'open', 'promo_interval', 'month_map'], axis = 1)

# %% [markdown]
# # 4.0 Exploratore Data Analisys (EDA)

# %%
df4 = df3.copy()

# %% [markdown]
# ## 4.1 Análise Univariada

# %% [markdown]
# ### 4.1.1 Response Variable

# %%
sns.distplot(df4['sales'], kde = False)
# Out:
# <AxesSubplot:xlabel='sales'>

# %% [markdown]
# ### 4.1.2 Numerical Variable

# %%
num_atributes.hist(bins = 25);

# %% [markdown]
# ### 4.1.3 Categorical Variable

# %%
cat_atributes.head()
# Out:
#   state_holiday store_type assortment   promo_interval month_map
# 0             0          c          a                0       Jul
# 1             0          a          a  Jan,Apr,Jul,Oct       Jul
# 2             0          a          a  Jan,Apr,Jul,Oct       Jul
# 3             0          c          c                0       Jul
# 4             0          a          a                0       Jul

# %%
df4['assortment'].drop_duplicates()
# Out:
# 0         basic
# 3      extended
# 258       extra
# Name: assortment, dtype: object

# %%
plt.subplot(3,2,1)
a = df4[df4['state_holiday'] != 'regular_day']
sns.countplot(a['state_holiday']);

plt.subplot(3,2,2)
sns.kdeplot(df4[df4['state_holiday'] == 'public_holiday']['sales'], label = 'public_holiday', shade = True);
sns.kdeplot(df4[df4['state_holiday'] == 'easter_holiday']['sales'], label = 'easter_holiday', shade = True);
sns.kdeplot(df4[df4['state_holiday'] == 'christmas']['sales'], label = 'christmas', shade = True);


plt.subplot(3,2,3)
sns.countplot(df4['store_type'])

plt.subplot(3,2,4)
sns.kdeplot(df4[df4['store_type'] == 'a']['sales'], label = 'a', shade = True);
sns.kdeplot(df4[df4['store_type'] == 'b']['sales'], label = 'b', shade = True);
sns.kdeplot(df4[df4['store_type'] == 'c']['sales'], label = 'c', shade = True);
sns.kdeplot(df4[df4['store_type'] == 'd']['sales'], label = 'd', shade = True);


plt.subplot(3,2,5)
sns.countplot(df4['assortment'])

plt.subplot(3,2,6)
sns.kdeplot(df4[df4['assortment'] == 'basic']['sales'], label = 'basic', shade = True);
sns.kdeplot(df4[df4['assortment'] == 'extended']['sales'], label = 'extended', shade = True);
sns.kdeplot(df4[df4['assortment'] == 'extra']['sales'], label = 'extra', shade = True);

# %% [markdown]
# ## 4.2 Análise Bivariada

# %% [markdown]
# ### H1. Lojas com maior sortimentos deveriam vender mais.
# #### Falso, lojas com maior sortimento vendem menos.

# %%
aux1 = df4[['assortment', 'sales']].groupby('assortment').sum().reset_index()
sns.barplot(x = 'assortment', y = 'sales', data = aux1)

aux2 = df4[['year_week', 'assortment', 'sales']].groupby(['year_week', 'assortment']).sum().reset_index()
aux2
# Out:
#     year_week assortment     sales
# 0     2013-00      basic  13434262
# 1     2013-00   extended  12425669
# 2     2013-00      extra    269404
# 3     2013-01      basic  26007250
# 4     2013-01   extended  22917693
# ..        ...        ...       ...
# 406   2015-29   extended  19570832
# 407   2015-29      extra    574020
# 408   2015-30      basic  23492454
# 409   2015-30   extended  23301780
# 410   2015-30      extra    436689
#
# [411 rows x 3 columns]

# %%
aux2.pivot(index = 'year_week', columns = 'assortment', values = 'sales').plot();

# %%
aux3 = df4[df4['assortment'] == 'extra']
aux3 = aux3[['year_week', 'assortment', 'sales']].groupby(['year_week', 'assortment']).sum().reset_index()
aux3.pivot(index = 'year_week', columns = 'assortment', values = 'sales').plot();

# %% [markdown]
# ### H2. Lojas com competidores mais próximos deveriam vender menos.
# #### Falço, lojas com competidores mais próximos vendem mais

# %%
aux1 = df4[['competition_distance', 'sales']].groupby('competition_distance').sum().reset_index()

plt.subplot(1,3,1)
sns.scatterplot(x = 'competition_distance', y = 'sales', data = aux1)

plt.subplot(1,3,2)
bins = list(np.arange(0, 20000, 1000))
aux1['competition_distance_binned'] = pd.cut(aux1['competition_distance'], bins = bins)
aux2 = aux1[['competition_distance_binned', 'sales']].groupby('competition_distance_binned').sum().reset_index()
sns.barplot(x = 'competition_distance_binned', y = 'sales', data = aux2);
plt.xticks(rotation = 90);

plt.subplot(1,3,3)
sns.heatmap(aux1.corr(method = 'pearson'), annot = True);

# %% [markdown]
# ### H3. Lojas com competidores à mais tempo deveriam vender mais.
# #### Falso, pois lojas com competidores a mais tempo vendem menos.
# #### Valores negativos informam que um competidor estava previsto para ser aberto, ou seja estavam vendendo muito bem e um competidor surgiu

# %%
plt.subplot(1,3,1)
aux1 = df4[['competition_time_month', 'sales']].groupby('competition_time_month' ).sum().reset_index()
aux2 = aux1[( aux1['competition_time_month'] < 120 ) & (aux1['competition_time_month'] != 0 )]
sns.barplot( x='competition_time_month', y='sales', data=aux2 );
plt.xticks( rotation=90 );

plt.subplot(1,3,2)
sns.regplot(x = 'competition_time_month', y = 'sales', data = aux2)

plt.subplot(1,3,3)
sns.heatmap(aux1.corr(method = 'pearson'), annot = True)
# Out:
# <AxesSubplot:>

# %%
aux1
# Out:
#      competition_time_month    sales
# 0                       -32   198200
# 1                       -31   993663
# 2                       -30  2232685
# 3                       -29  3175827
# 4                       -28  4157527
# ..                      ...      ...
# 371                    1403   153074
# 372                    1404   155301
# 373                    1405   154513
# 374                    1406   158205
# 375                    1407    38882
#
# [376 rows x 2 columns]

# %% [markdown]
# ### H4. Lojas com promoções ativas por mais tempo deveriam vender mais.
# #### Falso, lojas com promoçoes ativas por mais tempo vendem menos, depois de certo periodo perde a força.

# %%
aux1 = df4[['promo_time_week', 'sales']].groupby( 'promo_time_week').sum().reset_index()

grid = gridspec.GridSpec( 2, 3 )

#foi feito um zoom no gráfico promo_time_week versus sales para ver somente promoção regular e depois somente promoção extendida

plt.subplot( grid[0,0] )
aux2 = aux1[aux1['promo_time_week'] > 0] # promo extendido
sns.barplot( x='promo_time_week', y='sales', data=aux2 );
plt.xticks( rotation=90 );

plt.subplot( grid[0,1] )
sns.regplot( x='promo_time_week', y='sales', data=aux2 );

plt.subplot( grid[1,0] )
aux3 = aux1[aux1['promo_time_week'] < 0] # promo regular
sns.barplot( x='promo_time_week', y='sales', data=aux3 );
plt.xticks( rotation=90 );

plt.subplot( grid[1,1] )
sns.regplot( x='promo_time_week', y='sales', data=aux3 );

plt.subplot( grid[:,2] )
sns.heatmap( aux1.corr( method='pearson' ), annot=True );

# %% [markdown]
# ### <s>H5. Lojas com mais dias de promoção deveriam vender mais.

# %% [markdown]
# ### 6. Lojas com mais promoções consecutivas deveriam vender mais.
# #### Falso, porque lojas com promoções consecutivas vendem menos.

# %%
 df4[['promo', 'promo2', 'sales']].groupby( ['promo', 'promo2'] ).sum().reset_index()
# Out:
#    promo  promo2       sales
# 0      0       0  1482612096
# 1      0       1  1289362241
# 2      1       0  1628930532
# 3      1       1  1472275754

# %%
aux1 = df4[( df4['promo'] == 1 ) & ( df4['promo2'] == 1 )][['year_week','sales']].groupby('year_week').sum().reset_index()
ax = aux1.plot()
aux2 = df4[( df4['promo'] == 1 ) & ( df4['promo2'] == 0 )][['year_week','sales']].groupby('year_week').sum().reset_index()
aux2.plot(ax = ax)
ax.legend( labels=['Tradicional & Extendida', 'Extendida']);

# %%
aux = df4[df4['state_holiday'] != 'regular_day']

plt.subplot( 1, 2, 1 )
aux1 = aux[['state_holiday', 'sales']].groupby('state_holiday').sum().reset_index()
sns.barplot( x='state_holiday', y='sales', data=aux1 );

plt.subplot( 1, 2, 2 )
aux2 = aux[['year', 'state_holiday', 'sales']].groupby(['year','state_holiday']).sum().reset_index()

sns.barplot( x='year', y='sales', hue='state_holiday', data=aux2 );

# %% [markdown]
# ### 8. Lojas abertas durante o feriado de Natal deveriam vender mais.
# #### FALSA Lojas abertas durante o feriado do Natal vendem menos.

# %%
aux = df4[df4['state_holiday'] != 'regular_day']

plt.subplot( 1, 2, 1 )
aux1 = aux[['state_holiday', 'sales']].groupby( 'state_holiday' ).sum().reset_index()
sns.barplot( x='state_holiday', y='sales', data=aux1 );

plt.subplot( 1, 2, 2 )
aux2 = aux[['year', 'state_holiday', 'sales']].groupby( ['year','state_holiday'] ).sum().reset_index()
sns.barplot( x='year', y='sales', hue='state_holiday', data=aux2 );

# %% [markdown]
# ### 9. Lojas deveriam vender mais ao longo dos anos.
# #### FALSA Lojas vendem menos ao longo dos anos

# %%
aux1 = df4[['year', 'sales']].groupby( 'year' ).sum().reset_index()

plt.subplot( 1, 3, 1 )
sns.barplot( x='year', y='sales', data=aux1 );

plt.subplot( 1, 3, 2 )
sns.regplot( x='year', y='sales', data=aux1 );

plt.subplot( 1, 3, 3 )
sns.heatmap( aux1.corr( method='pearson' ), annot=True );

# %% [markdown]
# ### 10. Lojas deveriam vender mais no segundo semestre do ano.
# #### FALSA Lojas vendem menos no segundo semestre do ano.

# %%
aux1 = df4[['month', 'sales']].groupby( 'month' ).sum().reset_index()

plt.subplot( 1, 3, 1 )
sns.barplot( x='month', y='sales', data=aux1 );

plt.subplot( 1, 3, 2 )
sns.regplot( x='month', y='sales', data=aux1 );

plt.subplot( 1, 3, 3 )
sns.heatmap( aux1.corr( method='pearson' ), annot=True );

# %% [markdown]
# ### 11. Lojas deveriam vender mais depois do dia 10 de cada mês.
# #### VERDADEIRA Lojas vendem mais depois do dia 10 de cada mes

# %%
aux1 = df4[['day', 'sales']].groupby( 'day' ).sum().reset_index()

plt.subplot( 2, 2, 1 )
sns.barplot( x='day', y='sales', data=aux1 );

plt.subplot( 2, 2, 2 )
sns.regplot( x='day', y='sales', data=aux1 );

plt.subplot( 2, 2, 3 )
sns.heatmap( aux1.corr( method='pearson' ), annot=True );
aux1['before_after'] = aux1['day'].apply( lambda x: 'before_10_days' if x <= 10 else 'after_10_days' )
aux2 =aux1[['before_after', 'sales']].groupby( 'before_after' ).sum().reset_index()

plt.subplot( 2, 2, 4 )
sns.barplot( x='before_after', y='sales', data=aux2 );

# %% [markdown]
# ### 12. Lojas deveriam vender menos aos finais de semana.
# #### VERDADEIRA Lojas vendem menos nos final de semana

# %%
aux1 = df4[['day_of_week', 'sales']].groupby( 'day_of_week' ).sum().reset_index()

plt.subplot( 1, 3, 1 )
sns.barplot( x='day_of_week', y='sales', data=aux1 );

plt.subplot( 1, 3, 2 )
sns.regplot( x='day_of_week', y='sales', data=aux1 );

plt.subplot( 1, 3, 3 )
sns.heatmap( aux1.corr( method='pearson' ), annot=True );

# %% [markdown]
# ### 13. Lojas deveriam vender menos durante os feriados escolares.
# #### VERDADEIRA Lojas vendem menos durante os feriadso escolares, except os meses de Julho e Agosto.

# %%
aux1 = df4[['school_holiday', 'sales']].groupby( 'school_holiday' ).sum().reset_index()

plt.subplot( 2, 1, 1 )
sns.barplot( x='school_holiday', y='sales', data=aux1 );
aux2 = df4[['month', 'school_holiday', 'sales']].groupby(['month','school_holiday'] ).sum().reset_index()

plt.subplot( 2, 1, 2 )
sns.barplot( x='month', y='sales', hue='school_holiday', data=aux2 );

# %%
tab =[['Hipoteses', 'Conclusao', 'Relevancia'],
['H1', 'Falsa', 'Baixa'],
['H2', 'Falsa', 'Media'],
['H3', 'Falsa', 'Media'],
['H4', 'Falsa', 'Baixa'],
['H5', '-', '-'],
['H7', 'Falsa', 'Baixa'],
['H8', 'Falsa', 'Media'],
['H9', 'Falsa', 'Alta'],
['H10', 'Falsa', 'Alta'],
['H11', 'Verdadeira', 'Alta'],
['H12', 'Verdadeira', 'Alta'],
['H13', 'Verdadeira', 'Baixa'],
]
print( tabulate( tab, headers='firstrow' ) )
# Out:
# Hipoteses    Conclusao    Relevancia
# -----------  -----------  ------------
# H1           Falsa        Baixa
# H2           Falsa        Media
# H3           Falsa        Media
# H4           Falsa        Baixa
# H5           -            -
# H7           Falsa        Baixa
# H8           Falsa        Media
# H9           Falsa        Alta
# H10          Falsa        Alta
# H11          Verdadeira   Alta
# H12          Verdadeira   Alta
# H13          Verdadeira   Baixa

# %% [markdown]
# ## 4.3 Análise Multivariada

# %% [markdown]
# ### 4.3.2 Numerical Variable

# %%
sns.heatmap(num_atributes.corr(method = 'pearson'), annot = True);

# %% [markdown]
# ### 4.3.3 Categorical Variable

# %%
a = df4.select_dtypes(include = 'object')

# %%
a.head()
# Out:
#   state_holiday store_type assortment year_week
# 0   regular_day          c      basic   2015-30
# 1   regular_day          a      basic   2015-30
# 2   regular_day          a      basic   2015-30
# 3   regular_day          c   extended   2015-30
# 4   regular_day          a      basic   2015-30

# %% [markdown]
# #### GERANDO A FÓRMULA CRAMER V

# %%
cm = pd.crosstab(a['state_holiday'], a['store_type'])
cm
# Out:
# store_type           a      b       c       d
# state_holiday
# christmas            4     66       0       1
# easter_holiday      36    100       0       9
# public_holiday     236    285      65     108
# regular_day     456766  15109  112903  258650

# %%
cm = pd.crosstab(a['state_holiday'], a['store_type']).values
cm
# Out:
# array([[     4,     66,      0,      1],
#        [    36,    100,      0,      9],
#        [   236,    285,     65,    108],
#        [456766,  15109, 112903, 258650]], dtype=int64)

# %%
chi2 = ss.chi2_contingency(cm)
chi2
# Out:
# (12792.159524019908,
#  0.0,
#  9,
#  array([[3.84324548e+01, 1.30843335e+00, 9.49942795e+00, 2.17596839e+01],
#         [7.84888161e+01, 2.67215262e+00, 1.94002402e+01, 4.44387911e+01],
#         [3.75663713e+02, 1.27894753e+01, 9.28535634e+01, 2.12693248e+02],
#         [4.56549415e+05, 1.55432299e+04, 1.12846247e+05, 2.58489108e+05]]))

# %%
n = cm.sum()
r, k = cm.shape
print(n)
print(r)
print(k)
# Out:
# 844338
# 4
# 4

# %%
chi2 = chi2[0]
chi2
# Out:
# 12792.159524019908

# %%
v = np.sqrt((chi2/n) / (min(k-1, r-1)))
v
# Out:
# 0.07106457093267678

# %% [markdown]
# #### GERANDO A CORRELAÇÃO

# %%
a1 = cramer_v( a['state_holiday'], a['state_holiday'] )
a2 = cramer_v( a['state_holiday'], a['store_type'] )
a3 = cramer_v( a['state_holiday'], a['assortment'] )

a4 = cramer_v( a['store_type'], a['state_holiday'] )
a5 = cramer_v( a['store_type'], a['store_type'] )
a6 = cramer_v( a['store_type'], a['assortment'] )

a7 = cramer_v( a['assortment'], a['state_holiday'] )
a8 = cramer_v( a['assortment'], a['store_type'] )
a9 = cramer_v( a['assortment'], a['assortment'] )

# Final dataset
d = pd.DataFrame( {'state_holiday': [a1, a2, a3], 'store_type': [a4, a5, a6], 'assortment': [a7, a8, a9] })

d = d.set_index( d.columns )
sns.heatmap( d, annot=True )
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 5.0 Data Preparation

# %%
df5 = df4.copy()

# %% [markdown]
# ## 5.1 Normalização

# %% [markdown]
# ## 5.2 Reescaling

# %%
rs = RobustScaler()
mms = MinMaxScaler()

#competition distance
df5['competition_distance'] = rs.fit_transform(df5[['competition_distance']].values)
pickle.dump(rs, open('parameter/competition_distance_scaler.pkl', 'wb'))

#competition time month
df5['competition_time_month'] = rs.fit_transform(df5[['competition_time_month']].values)
pickle.dump(rs, open('parameter/competition_time_month_scaler.pkl', 'wb'))

#promo time week
df5['promo_time_week'] = mms.fit_transform(df5[['promo_time_week']].values)
pickle.dump(rs, open('parameter/promo_time_week_scaler.pkl', 'wb'))

#year
df5['year'] = mms.fit_transform(df5[['year']].values)
pickle.dump(rs, open('parameter/year_scaler.pkl', 'wb'))

# %%
sns.distplot(df5['competition_distance']);

# %% [markdown]
# ## 5.3 Transformação

# %% [markdown]
# ### 5.3.1 Encoding

# %%
#state_holiday - One Hot Encoding
df5 = pd.get_dummies(df5, prefix=['state_holiday'], columns=['state_holiday'])

# store_type - Label Encoding
le = LabelEncoder()
df5['store_type'] = le.fit_transform(df5['store_type'])
pickle.dump(le, open('parameter/store_type_scaler.pkl', 'wb'))

#assortment - Ordinal Encoding
assortment_dict = {'basic': 1, 'extra': 2, 'extended': 3}
df5['assortment'] = df5['assortment'].map(assortment_dict)

# %% [markdown]
# ### 5.3.2 Response Transformation

# %%
df5['sales'] = np.log1p(df5['sales'])

# %% [markdown]
# ### 5.3.3 Transformação de natureza (aquelas cíclicas)

# %%
# day of week
df5['day_of_week_sin'] = df5['day_of_week'].apply(lambda x: np.sin(x * ( 2. *np.pi/7 )))
df5['day_of_week_cos'] = df5['day_of_week'].apply(lambda x: np.cos(x * ( 2. *np.pi/7 )))

# month
df5['month_sin'] = df5['month'].apply(lambda x: np.sin(x * (2. * np.pi/12)))
df5['month_cos'] = df5['month'].apply(lambda x: np.cos(x * (2. * np.pi/12)))

# day
df5['day_sin'] = df5['day'].apply( lambda x: np.sin(x * ( 2. * np.pi/30 )))
df5['day_cos'] = df5['day'].apply( lambda x: np.cos(x * ( 2. * np.pi/30 )))

# week of year
df5['week_of_year_sin'] = df5['week_of_year'].apply( lambda x: np.sin(x * ( 2.* np.pi/52 )))
df5['week_of_year_cos'] = df5['week_of_year'].apply( lambda x: np.cos(x * ( 2.* np.pi/52 )))

# %%
df5.head()
# Out:
#    store  day_of_week       date     sales  promo  school_holiday  store_type  \
# 0      1            5 2015-07-31  8.568646      1               1           2
# 1      2            5 2015-07-31  8.710290      1               1           0
# 2      3            5 2015-07-31  9.025816      1               1           0
# 3      4            5 2015-07-31  9.546527      1               1           2
# 4      5            5 2015-07-31  8.481151      1               1           0
#
#    assortment  competition_distance  competition_open_since_month  ...  \
# 0           1             -0.170968                             9  ...
# 1           1             -0.283871                            11  ...
# 2           1              1.903226                            12  ...
# 3           3             -0.275806                             9  ...
# 4           1              4.448387                             4  ...
#
#    state_holiday_public_holiday  state_holiday_regular_day  day_of_week_sin  \
# 0                             0                          1        -0.974928
# 1                             0                          1        -0.974928
# 2                             0                          1        -0.974928
# 3                             0                          1        -0.974928
# 4                             0                          1        -0.974928
#
#    day_of_week_cos  month_sin  month_cos   day_sin   day_cos  \
# 0        -0.222521       -0.5  -0.866025  0.207912  0.978148
# 1        -0.222521       -0.5  -0.866025  0.207912  0.978148
# 2        -0.222521       -0.5  -0.866025  0.207912  0.978148
# 3        -0.222521       -0.5  -0.866025  0.207912  0.978148
# 4        -0.222521       -0.5  -0.866025  0.207912  0.978148
#
#    week_of_year_sin week_of_year_cos
# 0         -0.568065        -0.822984
# 1         -0.568065        -0.822984
# 2         -0.568065        -0.822984
# 3         -0.568065        -0.822984
# 4         -0.568065        -0.822984
#
# [5 rows x 36 columns]

# %% [markdown]
# # 6.0 Feature Selector

# %%
df6 = df5.copy()

# %%
df6 = df6.drop(['week_of_year', 'day', 'month', 'day_of_week', 'promo_since', 'competition_since', 'year_week'],axis = 1)

# %% [markdown]
# ## 6.1 Separando Treino e teste

# %%
#últimas 6 semanas serão teste
df6[['store', 'date']].groupby('store').max().reset_index()['date'][0] - datetime.timedelta(days = 7)

#train
X_train = df6[df6['date'] < '2015-06-19']
Y_train = X_train['sales']

#test
X_test = df6[df6['date'] >= '2015-06-19']
Y_test = X_test['sales']

# %% [markdown]
# ## 6.2 Boruta selector (selecionando as features pelo boruta)

# %%
## trining and test dataset
#X_train_n = X_train.drop(['date', 'sales'], axis = 1).values
#Y_train_n= Y_train.values.ravel()
#
##define RandomForest
#rf = RandomForestRegressor(n_jobs = -1)
#
##define Boruta
##boruta = BorutaPy(rf, n_estimators = 'auto', verbose = 2, random_state = 42).fit(X_train_n, Y_train_n)

# %%
#cols_selected = boruta.support_.tolist()
#
##best selected
#X_train_fs = X_train.drop(['date', 'sales'], axis = 1)
#cols_selected_boruta = X_train_fs.iloc[:, cols_selected].columns.to_list()
#
##not selexted boruta
#cols_not_selected = #list(np.setdiff1d(X_train_fs.columns, #cols_selected_boruta))

# %%
tab
# Out:
# [['Hipoteses', 'Conclusao', 'Relevancia'],
#  ['H1', 'Falsa', 'Baixa'],
#  ['H2', 'Falsa', 'Media'],
#  ['H3', 'Falsa', 'Media'],
#  ['H4', 'Falsa', 'Baixa'],
#  ['H5', '-', '-'],
#  ['H7', 'Falsa', 'Baixa'],
#  ['H8', 'Falsa', 'Media'],
#  ['H9', 'Falsa', 'Alta'],
#  ['H10', 'Falsa', 'Alta'],
#  ['H11', 'Verdadeira', 'Alta'],
#  ['H12', 'Verdadeira', 'Alta'],
#  ['H13', 'Verdadeira', 'Baixa']]

# %%
cols_selected_boruta = [
'store',
'promo',
'store_type',
'assortment',
'competition_distance',
'competition_open_since_month',
'competition_open_since_year',
'promo2',
'promo2_since_week',
'promo2_since_year',
'competition_time_month',
'promo_time_week',
'day_of_week_sin',
'day_of_week_cos',
'month_sin',
'month_cos',
'day_sin',
'day_cos',
'week_of_year_sin',
'week_of_year_cos']
feat_to_add = ['date', 'sales']
cols_selected_boruta_full = cols_selected_boruta.copy()
cols_selected_boruta_full.extend(feat_to_add)

# %%
cols_selected_boruta
# Out:
# ['store',
#  'promo',
#  'store_type',
#  'assortment',
#  'competition_distance',
#  'competition_open_since_month',
#  'competition_open_since_year',
#  'promo2',
#  'promo2_since_week',
#  'promo2_since_year',
#  'competition_time_month',
#  'promo_time_week',
#  'day_of_week_sin',
#  'day_of_week_cos',
#  'month_sin',
#  'month_cos',
#  'day_sin',
#  'day_cos',
#  'week_of_year_sin',
#  'week_of_year_cos']

# %% [markdown]
# # 7.0 Machine Learning Modelling

# %%
#para o treinamento normal
x_train = X_train[cols_selected_boruta]
x_test = X_test[cols_selected_boruta]

# %%
#para o crossvalidation
x_training = X_train[cols_selected_boruta_full]

# %% [markdown]
# ## 7.1 Average Model

# %%
aux1 = x_test.copy()
aux1['sales']  = Y_test.copy()

#prediction
aux2 = aux1[['store', 'sales']].groupby('store').mean().reset_index().rename(columns = {'sales': 'prediction'})
aux1 = pd.merge(aux1, aux2, how = 'left', on = 'store')
yhat_baseline = aux1['prediction']

#performance
baseline_result = ml_error('Average Model', np.expm1(Y_test), np.expm1(yhat_baseline))
baseline_result
# Out:
#       Model Name          MAE      MAPE         RMSE
# 0  Average Model  1354.800353  0.455051  1835.135542

# %% [markdown]
# ## 7.2 Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
# model
lr = LinearRegression().fit(x_train, Y_train)


# prediction
yhat_lr = lr.predict(x_test)


# performance
lr_result = ml_error('Linear Regression', np.expm1(Y_test), np.expm1(yhat_lr))
lr_result
# Out:
#           Model Name          MAE      MAPE         RMSE
# 0  Linear Regression  1867.089774  0.292694  2671.049215

# %% [markdown]
# ### 7.2.1 Liner Regression Model - Crossvalidated

# %%
lr_result_cv = crossvalidation(x_training, kfold = 5, model_name = 'Linear Regression', model = LinearRegression())
lr_result_cv
# Out:
#           Model_name              MAE_CV       MAPE_CV             RMSE_CV
# 0  Linear Regression  2081.73 +/- 295.63  0.3 +/- 0.02  2952.52 +/- 468.37

# %% [markdown]
# ## 7.3 Liner Regression Regularized Model - Singular

# %%
from sklearn.linear_model import Lasso

# %%
#model
lrr = Lasso(alpha = 0.01).fit(x_train, Y_train)


#prediction
yhat_lrr = lrr.predict(x_test)


#performance
lrr_result = ml_error('Linear Regression Regularized', np.expm1(Y_test), np.expm1(yhat_lrr))
lrr_result
# Out:
#                       Model Name          MAE      MAPE         RMSE
# 0  Linear Regression Regularized  1891.704881  0.289106  2744.451737

# %% [markdown]
# ### 7.3.1 Liner Regression Regularized Model - Crosvalidated

# %%
lrr_result_cv = crossvalidation(x_training, kfold = 5, model_name = 'Linear Regression Regularized', model = Lasso(alpha = 0.01))
lrr_result_cv
# Out:
#                       Model_name             MAE_CV        MAPE_CV  \
# 0  Linear Regression Regularized  2116.38 +/- 341.5  0.29 +/- 0.01
#
#               RMSE_CV
# 0  3057.75 +/- 504.26

# %% [markdown]
# ## 7.4 RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
#model
rf = RandomForestRegressor(n_estimators = 100, n_jobs = -1, random_state = 42).fit(x_train, Y_train)


#prediction
yhat_rf = rf.predict(x_test)


#performance
rf_result = ml_error('Random Forest', np.expm1(Y_test), np.expm1(yhat_rf))
rf_result
# Out:
#       Model Name         MAE      MAPE         RMSE
# 0  Random Forest  679.598831  0.099913  1011.119437

# %% [markdown]
# ### 7.4.1 RandomForest - Crossvalidated

# %%
rf = RandomForestRegressor(n_estimators = 100, n_jobs = -1, random_state = 42).fit(x_train, Y_train)
rf_result_cv = crossvalidation(x_training, kfold = 5, model_name = 'Random Forest', model = rf)
rf_result_cv
# Out:
#       Model_name            MAE_CV        MAPE_CV            RMSE_CV
# 0  Random Forest  836.61 +/- 217.1  0.12 +/- 0.02  1254.3 +/- 316.17

# %% [markdown]
# ## 7.5 XGBoost Regressor

# %%
import xgboost as xgb

# %%
#model
model_xgb = xgb.XGBRegressor(objective = 'reg:squarederror',
                             n_estimators = 100,
                             eta = 0.01,
                             max_depth = 10,
                             subsample = 0.7,
                             colsample_bytree = 0.9).fit(x_train, Y_train)


#prediction
yhat_xgb = model_xgb.predict(x_test)


#performance
xgb_result = ml_error('XGBoost Forest Regressor', np.expm1(Y_test), np.expm1(yhat_xgb))
xgb_result
# Out:
#                  Model Name          MAE      MAPE         RMSE
# 0  XGBoost Forest Regressor  6683.423528  0.949439  7330.693347

# %% [markdown]
# ### 7.5.1 XGBoost Regressos - Crossvalidated

# %%
model_xgb = xgb.XGBRegressor(objective = 'reg:squarederror',
                             n_estimators = 100,
                             eta = 0.01,
                             max_depth = 10,
                             subsample = 0.7,
                             colsample_bytree = 0.9).fit(x_train, Y_train)
xgb_result_cv = crossvalidation(x_training, 5, 'XGBoost Regressor', model_xgb, verbose = True)
xgb_result_cv
# Out:
# 5
# 2014-11-20 00:00:00
# 2015-01-01 00:00:00
# 4
# 2015-01-01 00:00:00
# 2015-02-12 00:00:00
# 3
# 2015-02-12 00:00:00
# 2015-03-26 00:00:00
# 2
# 2015-03-26 00:00:00
# 2015-05-07 00:00:00
# 1
# 2015-05-07 00:00:00
# 2015-06-18 00:00:00
#           Model_name             MAE_CV       MAPE_CV            RMSE_CV
# 0  XGBoost Regressor  7049.2 +/- 588.65  0.95 +/- 0.0  7715.2 +/- 689.51

# %%
modelling_result = pd.concat([lr_result_cv, lrr_result_cv, rf_result_cv, xgb_result_cv])
modelling_result.sort_values('RMSE_CV')
# Out:
#                       Model_name              MAE_CV        MAPE_CV  \
# 0                  Random Forest    836.61 +/- 217.1  0.12 +/- 0.02
# 0              Linear Regression  2081.73 +/- 295.63   0.3 +/- 0.02
# 0  Linear Regression Regularized   2116.38 +/- 341.5  0.29 +/- 0.01
# 0              XGBoost Regressor   7049.2 +/- 588.65   0.95 +/- 0.0
#
#               RMSE_CV
# 0   1254.3 +/- 316.17
# 0  2952.52 +/- 468.37
# 0  3057.75 +/- 504.26
# 0   7715.2 +/- 689.51

# %% [markdown]
# # 8.0 Fine Tuning

# %% [markdown]
# ## 8.1 Random Search

# %%
#param = {'n_estimators': [1500, 1700, 2500, 3000, 3500],
#         'eta': [0.01, 0.03],
#         'max_depth': [3, 5, 9],
#         'subsample': [0.1, 0.5, 0.7],
#         'colsample_bytree': [0.3, 0.7, 0.9],
#         'min_child_weight': [3, 8, 15]}
#
#MAX_EVAL = 5

# %%
#final_result = pd.DataFrame()
#
#for i in range(MAX_EVAL):
#    hp = {k: random.sample(v, 1)[0] for k, v in param.items()}
#    print(hp)
#    
#    #model
#    #já treinei ele lá em cima então remove o fit
#    model_xgb = xgb.XGBRegressor(objective='reg:squarederror',
#                                  n_estimators=hp['n_estimators'],
#                                  eta=hp['eta'],
#                                  max_depth=hp['max_depth'],
#                                  subsample=hp['subsample'],
#                                  colsample_bytee=hp['colsample_bytree'],
#                                  min_child_weight=hp['min_child_weight'])
#    
#    #performance
#    result = crossvalidation(x_training, 5, 'XGBoost Regressor', model_xgb, verbose=True)
#    final_result = pd.concat([final_result, result])
#
#final_result

# %% [markdown]
# ## 8.2 Final Model

# %%
#melhor modelo: {'n_estimators': 350, 'eta': 0.01, 'max_depth': 9, 'subsample': 0.5, 'colsample_bytree': 0.7, 'min_child_weight': 15}
param_tuned = {'n_estimators': 350, 'eta': 0.01, 'max_depth': 9, 'subsample': 0.5, 'colsample_bytree': 0.7, 'min_child_weight': 15}

# %%
#model
model_xgb_tuned = xgb.XGBRegressor(objective = 'reg:squarederror',
                             n_estimators = param_tuned['n_estimators'],
                             eta = param_tuned['eta'],
                             max_depth = param_tuned['max_depth'],
                             subsample = param_tuned['subsample'],
                             colsample_bytree = param_tuned['colsample_bytree'],
                             min_child_weight = param_tuned['min_child_weight']).fit(x_train, Y_train)


#prediction
yhat_xgb_tuned = model_xgb_tuned.predict(x_test)


#performance
xgb_result_tuned = ml_error('XGBoost Forest Regressor', np.expm1(Y_test), np.expm1(yhat_xgb_tuned))
xgb_result_tuned
# Out:
#                  Model Name          MAE      MAPE         RMSE
# 0  XGBoost Forest Regressor  2041.354681  0.253072  2863.901751

# %% [markdown]
# # 9.0 Error Interpretation

# %%
df9 = X_test[cols_selected_boruta_full]
# rescale
df9['sales'] = np.expm1(df9['sales'])
df9['predictions'] = np.expm1(yhat_xgb_tuned)

# %% [markdown]
# ## 9.1 Business Performance

# %%
# sum of predictions
df91 = df9[['store', 'predictions']].groupby('store').sum().reset_index()

# %%
# MAE and MAPE
df9_aux1 = df9[['store', 'sales', 'predictions']].groupby('store').apply(lambda x: mean_absolute_error(x['sales'], x['predictions'])).reset_index().rename(columns={0:'MAE'})
df9_aux2 = df9[['store', 'sales', 'predictions']].groupby('store').apply(lambda x: mean_absolute_percentage_error(x['sales'], x['predictions'])).reset_index().rename(columns={0:'MAPE'})
df9_aux2
# Out:
#       store      MAPE
# 0         1  0.066773
# 1         2  0.161288
# 2         3  0.273009
# 3         4  0.382714
# 4         5  0.137823
# ...     ...       ...
# 1110   1111  0.161384
# 1111   1112  0.248630
# 1112   1113  0.162842
# 1113   1114  0.463332
# 1114   1115  0.278579
#
# [1115 rows x 2 columns]

# %%
# Merge
df9_aux3 = pd.merge(df9_aux1, df9_aux2, how='inner', on='store')
df92 = pd.merge(df91, df9_aux3, how='inner', on='store')

# Scenarios
df92['worst_scenario'] = df92['predictions'] - df92['MAE']
df92['best_scenario'] = df92['predictions'] + df92['MAE']

# %%
# order columns
df92 = df92[['store', 'predictions', 'worst_scenario', 'best_scenario', 'MAE','MAPE']]
df92
# Out:
#       store    predictions  worst_scenario  best_scenario           MAE  \
# 0         1  166723.906250   166431.444732  167016.367768    292.461518
# 1         2  154306.687500   153470.535849  155142.839151    836.151651
# 2         3  182272.187500   180328.462699  184215.912301   1943.724801
# 3         4  226447.234375   222584.240802  230310.227948   3862.993573
# 4         5  143214.078125   142518.492531  143909.663719    695.585594
# ...     ...            ...             ...            ...           ...
# 1110   1111  157802.531250   156979.163878  158625.898622    823.367372
# 1111   1112  234306.125000   232007.883499  236604.366501   2298.241501
# 1112   1113  202907.156250   201798.471548  204015.840952   1108.684702
# 1113   1114  444658.437500   433899.908652  455416.966348  10758.528848
# 1114   1115  184016.718750   182009.765124  186023.672376   2006.953626
#
#           MAPE
# 0     0.066773
# 1     0.161288
# 2     0.273009
# 3     0.382714
# 4     0.137823
# ...        ...
# 1110  0.161384
# 1111  0.248630
# 1112  0.162842
# 1113  0.463332
# 1114  0.278579
#
# [1115 rows x 6 columns]

# %%
df92.sort_values('MAPE', ascending=False).head()
# Out:
#      store    predictions  worst_scenario  best_scenario           MAE  \
# 424    425  195771.640625   193644.298921  197898.982329   2127.341704
# 841    842  229211.093750   215035.799171  243386.388329  14175.294579
# 542    543  153049.515625   151560.177484  154538.853766   1489.338141
# 697    698  217515.937500   206589.070933  228442.804067  10926.866567
# 787    788  235680.828125   224391.363901  246970.292349  11289.464224
#
#          MAPE
# 424  0.740748
# 841  0.692002
# 542  0.684225
# 697  0.649123
# 787  0.635198

# %%
sns.scatterplot(x='store', y='MAPE', data=df92)
# Out:
# <AxesSubplot:xlabel='store', ylabel='MAPE'>

# %% [markdown]
# ## 9.2 Total Performance

# %%
df93 = df92[['predictions', 'worst_scenario', 'best_scenario']].apply(lambda x : np.sum( x ), axis=0).reset_index().rename(columns={'index': 'Scenario', 0:'Values'})
df93['Values'] = df93['Values'].map('R${:,.2f}'.format)
df93
# Out:
#          Scenario            Values
# 0     predictions  R$213,131,360.00
# 1  worst_scenario  R$210,858,096.47
# 2   best_scenario  R$215,404,640.55

# %% [markdown]
# ## 9.3 ML Performance

# %%
df9['error'] = df9['sales'] - df9['predictions']
df9['error_rate'] = df9['predictions'] / df9['sales']

# %%
plt.subplot( 2, 2, 1 )
sns.lineplot(x='date', y='sales', data=df9, label='SALES')
sns.lineplot(x='date', y='predictions', data=df9, label='PREDICTIONS')

plt.subplot(2, 2, 2)
sns.lineplot(x='date', y='error_rate', data=df9)
plt.axhline(1, linestyle='--')

plt.subplot(2, 2, 3)
sns.distplot(df9['error'])

plt.subplot(2, 2, 4 )
sns.scatterplot(df9['predictions'], df9['error'])
# Out:
# <AxesSubplot:xlabel='predictions', ylabel='error'>

# %% [markdown]
# # 10.0 Deploy

# %%
pickle.dump(model_xgb_tuned, open('/users/leona/Comunidade_DS/repos/proj2_ds_em_prod/model/model_do_rossmann.pkl', 'wb'))

# %% [markdown]
# ## 10.1 Rassmann()

# %%
import pickle
import inflection
import pandas as pd
import numpy as np
import math
import datetime

class rossmann(object):
    
    def __init__(self):
        self.home_path = 'C:/Users/leona/Comunidade_DS/repos/proj2_ds_em_prod/'
        self.competition_distance_scaler = pickle.load(open(self.home_path + 'parameter/competition_distance_scaler.pkl', 'rb'))
        self.competition_time_month_scaler = pickle.load(open(self.home_path + 'parameter/competition_time_month_scaler.pkl', 'rb'))
        self.promo_time_week_scaler = pickle.load(open(self.home_path + 'parameter/promo_time_week_scaler.pkl', 'rb'))
        self.year_scaler = pickle.load(open(self.home_path + 'parameter/year_scaler.pkl', 'rb'))
        self.store_type_scaler = pickle.load(open(self.home_path + 'parameter/store_type_scaler.pkl', 'rb'))
        
    def cleaning(self, df1):
        # 1 LIMPEZA       
        ## 1.1 Rename columns
        cols_old = ['Store', 'DayOfWeek', 'Date', 'Open', 'Promo',
               'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
               'CompetitionDistance', 'CompetitionOpenSinceMonth',
               'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
               'Promo2SinceYear', 'PromoInterval']
        
        snakecase = lambda x : inflection.underscore(x)
        cols_new = list(map(snakecase, cols_old))
        df1.columns = cols_new
        
        
        ## 1.3 Data types
        df1['date'] = pd.to_datetime(df1['date'])
        
        ## 1.5 Fill NA
        #competition_distance
        # se não tem competidor, podemos supor que está muito longe
        df1['competition_distance'] = df1['competition_distance'].apply(lambda x : 200000.0 if math.isnan(x) else x)
        
        #competition_open_since_month 
        # se for na, copio a data da loja, pois pode possuir competidor mas a data de abertura não está explicita
        df1['competition_open_since_month'] = df1.apply(lambda x : x['date'].month if math.isnan(x['competition_open_since_month']) else x['competition_open_since_month'], axis = 1)
        
        #competition_open_since_year
        # se for na, copio a data da loja, pois pode possuir competidor mas a data de abertura não está explicita
        df1['competition_open_since_year'] = df1.apply(lambda x : x['date'].year if math.isnan(x['competition_open_since_year']) else x['competition_open_since_year'], axis = 1)
        
        #promo2_since_week   
        #a loja decidiu não parcitipar da segunda promoção, então substituo pela valor da data que ela começou para saber a partir de quando ela caiu fora
        df1['promo2_since_week'] = df1.apply(lambda x : x['date'].week if math.isnan(x['promo2_since_week']) else x['promo2_since_week'], axis = 1)
        
        #promo2_since_year
        #a loja decidiu não parcitipar da segunda promoção, então substituo pela valor da data que ela começou para saber a partir de quando ela caiu fora
        df1['promo2_since_year'] = df1.apply(lambda x : x['date'].year if math.isnan(x['promo2_since_year']) else x['promo2_since_year'], axis = 1)
        
        #promo_interval
        #para identifica os meses que a promo2 tava ativa
        month_map = {1: 'Jan', 2: 'Fev', 3: 'Mar', 4: 'Abr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Jun', 9: 'Aug', 10: 'Sep', 11: 'Nov', 12: 'Dez'}
        df1['promo_interval'].fillna(0, inplace = True)
        df1['month_map'] = df1['date'].dt.month.map(month_map)
        df1['is_promo'] = df1[['promo_interval', 'month_map']].apply(lambda x: 0 if x['promo_interval'] == 0 else 1 if x['month_map'] in x['promo_interval'].split(',') else 0, axis = 1)
        
        ## 1.6 Change dtypes
        df1['competition_open_since_month'] = df1['competition_open_since_month'].astype('int64')
        df1['competition_open_since_year'] = df1['competition_open_since_year'].astype('int64')
        df1['promo2_since_week'] = df1['promo2_since_week'].astype('int64')
        df1['promo2_since_year'] = df1['promo2_since_year'].astype('int64')
        
        return df1

    def feature_eng(self, df2):
        # 2 FEATURE ENGINEERING 
        #year
        df2['year'] = df2['date'].dt.year
        
        #month
        df2['month'] = df2['date'].dt.month
        
        #day
        df2['day'] = df2['date'].dt.day
        
        #week of year
        df2['week_of_year'] = df2['date'].dt.weekofyear
        
        #year week
        df2['year_week'] = df2['date'].dt.strftime('%Y-%W')
        
        #competition since month
        #juntei o ano com o mês, com isso subtrai com a data, dividi por 30 para deixar em mês, e isolei esse resultado com ox.days
        df2['competition_since'] = df2.apply( lambda x : datetime.datetime(year=x['competition_open_since_year'], month=x['competition_open_since_month'],day=1 ), axis=1 )
        df2['competition_time_month'] = ( ( df2['date'] - df2['competition_since'] )/30).apply( lambda x: x.days ).astype( int )
        
        #promo since week
        #juntei o ano e a semana do ano como string da promoção, apliquei strptime para adicionar dia e transformar em data, subtrai por 7 para pegar o início da semana, depois dividi por sete na subtração para tirar isolar o resultado com o x.days
        df2['promo_since'] = df2['promo2_since_year'].astype( str ) + '-' + df2['promo2_since_week'].astype( str )
        df2['promo_since'] = df2['promo_since'].apply( lambda x: datetime.datetime.strptime( x + '-1', '%Y-%W-%w' ) - datetime.timedelta( days=7 ) )
        df2['promo_time_week'] = ( ( df2['date'] - df2['promo_since'] )/7 ).apply(lambda x: x.days ).astype( int )
        
        #assortment
        df2['assortment'] = df2['assortment'].apply( lambda x: 'basic' if x == 'a' else 'extra' if x == 'b' else 'extended' )
        
        #state holiday
        df2['state_holiday'] = df2['state_holiday'].apply( lambda x: 'public_holiday' if x == 'a' else 'easter_holiday' if x == 'b' else 'christmas' if x == 'c' else 'regular_day' )
        
        # 3 FILTRO
        
        #quando a loja ta fechada não tem venda
        df2 = df2[(df2['open'] != 0)]
        
        #não saberei quantos clientes terão na loja para ajudar na prediçã no futuro
        df3 = df2.drop(['open', 'promo_interval', 'month_map'], axis = 1).copy()
        
        return df3
    
    def preparation(self, df4):
        # 5 DATA PREPARATION
        ## 5.2 Reescaling
        #competition distance
        df4['competition_distance'] = self.competition_distance_scaler.fit_transform(df4[['competition_distance']].values)
        
        #competition time month
        df4['competition_time_month'] = self.competition_time_month_scaler.fit_transform(df4[['competition_time_month']].values)
        
        #promo time week
        df4['promo_time_week'] = self.promo_time_week_scaler.fit_transform(df4[['promo_time_week']].values)
        
        #year
        df4['year'] = self.year_scaler.fit_transform(df4[['year']].values)
    
    
        ## 5.3 Transformação
        ### 5.3.1 Encoding
        #state_holiday - One Hot Encoding
        df4 = pd.get_dummies(df4, prefix=['state_holiday'], columns=['state_holiday'])
        
        # store_type - Label Encoding
        df4['store_type'] = self.store_type_scaler.fit_transform(df4['store_type'])
        
        #assortment - Ordinal Encoding
        assortment_dict = {'basic': 1, 'extra': 2, 'extended': 3}
        df4['assortment'] = df4['assortment'].map(assortment_dict)
    
        ### 5.3.3 Transformação de natureza (aquelas cíclicas)
        
        # day of week
        df4['day_of_week_sin'] = df4['day_of_week'].apply(lambda x: np.sin(x * ( 2. *np.pi/7 )))
        df4['day_of_week_cos'] = df4['day_of_week'].apply(lambda x: np.cos(x * ( 2. *np.pi/7 )))
        
        # month
        df4['month_sin'] = df4['month'].apply(lambda x: np.sin(x * (2. * np.pi/12)))
        df4['month_cos'] = df4['month'].apply(lambda x: np.cos(x * (2. * np.pi/12)))
        
        # day
        df4['day_sin'] = df4['day'].apply( lambda x: np.sin(x * ( 2. * np.pi/30 )))
        df4['day_cos'] = df4['day'].apply( lambda x: np.cos(x * ( 2. * np.pi/30 )))
        
        # week of year
        df4['week_of_year_sin'] = df4['week_of_year'].apply( lambda x: np.sin(x * ( 2.* np.pi/52 )))
        df4['week_of_year_cos'] = df4['week_of_year'].apply( lambda x: np.cos(x * ( 2.* np.pi/52 )))
            
        df5 = df4[['store','promo','store_type','assortment', 'competition_distance', 'competition_open_since_month', 'competition_open_since_year', 'promo2', 'promo2_since_week', 'promo2_since_year', 'competition_time_month', 'promo_time_week', 'day_of_week_sin', 'day_of_week_cos', 'month_sin', 'month_cos', 'day_sin', 'day_cos', 'week_of_year_sin', 'week_of_year_cos']].copy()
        
        return df5
    
    def prediction(self, model, original_data, test_data):
        #predição
        prediction = model.predict(test_data)
        
        #juntando os dados
        original_data['prediction'] = np.expm1(prediction)
        return original_data.to_json(orient = 'records', date_format = 'iso')

# %% [markdown]
# ## 10.2 API Handler

# %%
import pandas as pd
import pickle
from flask import Flask, request, Response
from rossmann.Rossmann import rossmann

#instanciando as requisições
app = Flask(__name__)

#puchando meu modelo em memória
model = pickle.load(open('/users/leona/Comunidade_DS/repos/proj2_ds_em_prod/model/model_do_rossmann.pkl', 'rb'))

#ativando o endpoint
@app.route('/rossmann/predict', methods = ['POST'])

def rossmann_predict():
    #instanciando o json vindo da api
    test_json = request.get_json()
    
    #se tiver dados json
    if test_json:
        #se for uma única linha json
        if isinstance(test_json, dict):
            test_raw = pd.DataFrame(test_json, index = [0])
        #se for mais de uma linha json
        else:
            test_raw = pd.DataFrame(test_json, columns = test_json[0].keys())
        
        #instanciando minha classe
        pepiline = rossmann()
        
        #radando meu método de limpeza
        df1 = pepiline.cleaning(test_raw)
        
        #rodando meu método de feature eng
        df2 = pepiline.feature_eng(df1)
        
        #rodando meu método de preparação
        df3 = pepiline.preparation(df2)
        
        #rodando o modelo para predição
        df_response = pepiline.prediction(model, test_raw, df3)
        
        return df_response

    #se não haver dados na api
    else:
        return Response('{}', status = 200, mimetype = 'application/json')

#primeiro a rodas
if __name__ == '__main__':
    app.run('0.0.0.0')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [108], in <cell line: 4>()
#       2 import pickle
#       3 from flask import Flask, request, Response
# ----> 4 from rossmann.Rossmann import rossmann
#       6 #instanciando as requisições
#       7 app = Flask(__name__)
#
# ModuleNotFoundError: No module named 'rossmann'

# %% [markdown]
# ## 10.3 API Tester

# %%
import requests

# %%
df10 = pd.read_csv('C:/Users/leona/Comunidade_DS/repos/proj2_ds_em_prod/test.csv')
df10
# Out:
#           Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  \
# 0          1      1          4  2015-09-17   1.0      1            0
# 1          2      3          4  2015-09-17   1.0      1            0
# 2          3      7          4  2015-09-17   1.0      1            0
# 3          4      8          4  2015-09-17   1.0      1            0
# 4          5      9          4  2015-09-17   1.0      1            0
# ...      ...    ...        ...         ...   ...    ...          ...
# 41083  41084   1111          6  2015-08-01   1.0      0            0
# 41084  41085   1112          6  2015-08-01   1.0      0            0
# 41085  41086   1113          6  2015-08-01   1.0      0            0
# 41086  41087   1114          6  2015-08-01   1.0      0            0
# 41087  41088   1115          6  2015-08-01   1.0      0            0
#
#        SchoolHoliday
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 41083              0
# 41084              0
# 41085              0
# 41086              0
# 41087              1
#
# [41088 rows x 8 columns]

# %%
df_test = pd.merge(df10, df_store_raw, how = 'left', on = 'Store')
df_test = df_test[df_test['Open'] != 0]
df_test = df_test[~df_test['Open'].isnull()]
df_test = df_test.drop('Id', axis = 1)

# %%
df_test
# Out:
#        Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday  \
# 0          1          4  2015-09-17   1.0      1            0              0
# 1          3          4  2015-09-17   1.0      1            0              0
# 2          7          4  2015-09-17   1.0      1            0              0
# 3          8          4  2015-09-17   1.0      1            0              0
# 4          9          4  2015-09-17   1.0      1            0              0
# ...      ...        ...         ...   ...    ...          ...            ...
# 41083   1111          6  2015-08-01   1.0      0            0              0
# 41084   1112          6  2015-08-01   1.0      0            0              0
# 41085   1113          6  2015-08-01   1.0      0            0              0
# 41086   1114          6  2015-08-01   1.0      0            0              0
# 41087   1115          6  2015-08-01   1.0      0            0              1
#
#       StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0             c          a               1270.0                        9.0
# 1             a          a              14130.0                       12.0
# 2             a          c              24000.0                        4.0
# 3             a          a               7520.0                       10.0
# 4             a          c               2030.0                        8.0
# ...         ...        ...                  ...                        ...
# 41083         a          a               1900.0                        6.0
# 41084         c          c               1880.0                        4.0
# 41085         a          c               9260.0                        NaN
# 41086         a          c                870.0                        NaN
# 41087         d          c               5350.0                        NaN
#
#        CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                        2008.0       0              NaN              NaN
# 1                        2006.0       1             14.0           2011.0
# 2                        2013.0       0              NaN              NaN
# 3                        2014.0       0              NaN              NaN
# 4                        2000.0       0              NaN              NaN
# ...                         ...     ...              ...              ...
# 41083                    2014.0       1             31.0           2013.0
# 41084                    2006.0       0              NaN              NaN
# 41085                       NaN       0              NaN              NaN
# 41086                       NaN       0              NaN              NaN
# 41087                       NaN       1             22.0           2012.0
#
#           PromoInterval
# 0                   NaN
# 1       Jan,Apr,Jul,Oct
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 41083   Jan,Apr,Jul,Oct
# 41084               NaN
# 41085               NaN
# 41086               NaN
# 41087  Mar,Jun,Sept,Dec
#
# [35093 rows x 16 columns]

# %%
data = json.dumps(df_test.to_dict(orient = 'records'))

# %%
# API Call
#API LOCAL - Abrir pasta api e rodam no prompt o handler.py
#url = 'http://127.0.0.1:5000/rossmann/predict'

#API NUVEM - end point rossmann/predict
url = 'https://rossmannappapi.herokuapp.com/rossmann/predict'
header = {'Content-type': 'application/json'}
data = data

r = requests.post(url, data = data, headers = header)
print('Status Code {}'.format(r.status_code))
# Out:
# Status Code 200

# %%
df1_result = pd.DataFrame(r.json(), columns = r.json()[0].keys())

# %%
df2_result = df1_result[['store', 'prediction']].groupby('store').sum().reset_index()
df2_result
# Out:
#      store     prediction
# 0        1  182913.520508
# 1        3  200391.450195
# 2        7  228040.836670
# 3        8  186197.464844
# 4        9  229463.082520
# ..     ...            ...
# 851   1111  173404.861084
# 852   1112  228735.377441
# 853   1113  220798.836914
# 854   1114  445267.563477
# 855   1115  196293.127686
#
# [856 rows x 2 columns]

# %%
for i in range(len(df2_result)):
    print('Store {} are going to sell about R$ {:,.2f} in the 6 week fowards'.format(df2_result.loc[i, 'store'], df2_result.loc[i, 'prediction']))
# Out:
# Store 1 are going to sell about R$ 182,913.52 in the 6 week fowards
# Store 3 are going to sell about R$ 200,391.45 in the 6 week fowards
# Store 7 are going to sell about R$ 228,040.84 in the 6 week fowards
# Store 8 are going to sell about R$ 186,197.46 in the 6 week fowards
# Store 9 are going to sell about R$ 229,463.08 in the 6 week fowards
# Store 10 are going to sell about R$ 182,945.10 in the 6 week fowards
# Store 11 are going to sell about R$ 211,050.74 in the 6 week fowards
# Store 12 are going to sell about R$ 208,111.85 in the 6 week fowards
# Store 13 are going to sell about R$ 187,471.97 in the 6 week fowards
# Store 14 are going to sell about R$ 177,813.14 in the 6 week fowards
# Store 15 are going to sell about R$ 215,069.46 in the 6 week fowards
# Store 16 are going to sell about R$ 224,556.42 in the 6 week fowards
# Store 19 are going to sell about R$ 209,642.57 in the 6 week fowards
# Store 20 are going to sell about R$ 207,240.40 in the 6 week fowards
# Store 21 are going to sell about R$ 214,001.51 in the 6 week fowards
# Store 22 are going to sell about R$ 167,611.10 in the 6 week fowards
# Store 23 are going to sell about R$ 193,147.07 in the 6 week fowards
# Store 24 are going to sell about R$ 243,722.30 in the 6 week fowards
# Store 25 are going to sell about R$ 234,389.10 in the 6 week fowards
# Store 27 are going to sell about R$ 219,908.43 in the 6 week fowards
# Store 29 are going to sell about R$ 225,876.95 in the 6 week fowards
# Store 30 are going to sell about R$ 174,602.82 in the 6 week fowards
# Store 31 are going to sell about R$ 219,501.68 in the 6 week fowards
# Store 32 are going to sell about R$ 164,962.00 in the 6 week fowards
# Store 33 are going to sell about R$ 234,783.15 in the 6 week fowards
# Store 35 are going to sell about R$ 244,435.88 in the 6 week fowards
# Store 36 are going to sell about R$ 268,902.33 in the 6 week fowards
# Store 38 are going to sell about R$ 196,085.90 in the 6 week fowards
# Store 39 are going to sell about R$ 159,979.76 in the 6 week fowards
# Store 40 are going to sell about R$ 198,219.36 in the 6 week fowards
# Store 41 are going to sell about R$ 188,705.89 in the 6 week fowards
# Store 42 are going to sell about R$ 274,367.46 in the 6 week fowards
# Store 43 are going to sell about R$ 195,002.98 in the 6 week fowards
# Store 45 are going to sell about R$ 192,128.29 in the 6 week fowards
# Store 46 are going to sell about R$ 166,834.74 in the 6 week fowards
# Store 47 are going to sell about R$ 185,720.18 in the 6 week fowards
# Store 48 are going to sell about R$ 199,710.78 in the 6 week fowards
# Store 49 are going to sell about R$ 209,540.81 in the 6 week fowards
# Store 50 are going to sell about R$ 183,102.31 in the 6 week fowards
# Store 51 are going to sell about R$ 209,268.47 in the 6 week fowards
# Store 52 are going to sell about R$ 234,135.31 in the 6 week fowards
# Store 53 are going to sell about R$ 201,005.47 in the 6 week fowards
# Store 56 are going to sell about R$ 218,460.32 in the 6 week fowards
# Store 58 are going to sell about R$ 196,646.94 in the 6 week fowards
# Store 61 are going to sell about R$ 191,270.92 in the 6 week fowards
# Store 62 are going to sell about R$ 201,255.36 in the 6 week fowards
# Store 63 are going to sell about R$ 214,091.69 in the 6 week fowards
# Store 64 are going to sell about R$ 223,077.95 in the 6 week fowards
# Store 66 are going to sell about R$ 191,849.19 in the 6 week fowards
# Store 67 are going to sell about R$ 232,791.37 in the 6 week fowards
# Store 68 are going to sell about R$ 203,359.03 in the 6 week fowards
# Store 69 are going to sell about R$ 223,947.24 in the 6 week fowards
# Store 70 are going to sell about R$ 232,599.80 in the 6 week fowards
# Store 71 are going to sell about R$ 222,426.53 in the 6 week fowards
# Store 72 are going to sell about R$ 166,605.97 in the 6 week fowards
# Store 73 are going to sell about R$ 215,939.82 in the 6 week fowards
# Store 74 are going to sell about R$ 207,322.20 in the 6 week fowards
# Store 75 are going to sell about R$ 229,330.64 in the 6 week fowards
# Store 76 are going to sell about R$ 239,851.32 in the 6 week fowards
# Store 77 are going to sell about R$ 222,816.24 in the 6 week fowards
# Store 79 are going to sell about R$ 189,286.15 in the 6 week fowards
# Store 80 are going to sell about R$ 209,823.19 in the 6 week fowards
# Store 81 are going to sell about R$ 194,784.06 in the 6 week fowards
# Store 82 are going to sell about R$ 239,032.40 in the 6 week fowards
# Store 83 are going to sell about R$ 191,272.63 in the 6 week fowards
# Store 84 are going to sell about R$ 233,242.11 in the 6 week fowards
# Store 86 are going to sell about R$ 179,800.33 in the 6 week fowards
# Store 89 are going to sell about R$ 188,324.74 in the 6 week fowards
# Store 90 are going to sell about R$ 202,817.82 in the 6 week fowards
# Store 91 are going to sell about R$ 180,069.66 in the 6 week fowards
# Store 92 are going to sell about R$ 211,938.65 in the 6 week fowards
# Store 93 are going to sell about R$ 185,376.47 in the 6 week fowards
# Store 94 are going to sell about R$ 223,625.12 in the 6 week fowards
# Store 98 are going to sell about R$ 180,695.04 in the 6 week fowards
# Store 99 are going to sell about R$ 184,247.57 in the 6 week fowards
# Store 100 are going to sell about R$ 195,613.33 in the 6 week fowards
# Store 101 are going to sell about R$ 194,613.37 in the 6 week fowards
# Store 102 are going to sell about R$ 189,646.62 in the 6 week fowards
# Store 105 are going to sell about R$ 171,705.01 in the 6 week fowards
# Store 107 are going to sell about R$ 201,296.92 in the 6 week fowards
# Store 108 are going to sell about R$ 223,582.62 in the 6 week fowards
# Store 109 are going to sell about R$ 218,773.86 in the 6 week fowards
# Store 110 are going to sell about R$ 195,306.14 in the 6 week fowards
# Store 111 are going to sell about R$ 212,463.60 in the 6 week fowards
# Store 112 are going to sell about R$ 199,941.21 in the 6 week fowards
# Store 113 are going to sell about R$ 213,167.36 in the 6 week fowards
# Store 115 are going to sell about R$ 216,343.95 in the 6 week fowards
# Store 117 are going to sell about R$ 189,154.68 in the 6 week fowards
# Store 118 are going to sell about R$ 223,818.86 in the 6 week fowards
# Store 119 are going to sell about R$ 218,921.49 in the 6 week fowards
# Store 120 are going to sell about R$ 191,358.59 in the 6 week fowards
# Store 122 are going to sell about R$ 221,058.29 in the 6 week fowards
# Store 124 are going to sell about R$ 185,687.37 in the 6 week fowards
# Store 126 are going to sell about R$ 188,215.12 in the 6 week fowards
# Store 127 are going to sell about R$ 180,474.83 in the 6 week fowards
# Store 128 are going to sell about R$ 189,848.38 in the 6 week fowards
# Store 129 are going to sell about R$ 172,590.78 in the 6 week fowards
# Store 130 are going to sell about R$ 179,068.49 in the 6 week fowards
# Store 131 are going to sell about R$ 219,465.18 in the 6 week fowards
# Store 132 are going to sell about R$ 190,012.37 in the 6 week fowards
# Store 135 are going to sell about R$ 183,442.04 in the 6 week fowards
# Store 136 are going to sell about R$ 188,085.82 in the 6 week fowards
# Store 137 are going to sell about R$ 207,003.36 in the 6 week fowards
# Store 139 are going to sell about R$ 167,759.86 in the 6 week fowards
# Store 140 are going to sell about R$ 185,026.61 in the 6 week fowards
# Store 141 are going to sell about R$ 201,910.66 in the 6 week fowards
# Store 142 are going to sell about R$ 186,412.89 in the 6 week fowards
# Store 143 are going to sell about R$ 199,281.56 in the 6 week fowards
# Store 144 are going to sell about R$ 210,513.08 in the 6 week fowards
# Store 145 are going to sell about R$ 219,677.14 in the 6 week fowards
# Store 146 are going to sell about R$ 216,786.70 in the 6 week fowards
# Store 147 are going to sell about R$ 226,333.61 in the 6 week fowards
# Store 149 are going to sell about R$ 174,212.94 in the 6 week fowards
# Store 150 are going to sell about R$ 212,284.06 in the 6 week fowards
# Store 152 are going to sell about R$ 205,236.66 in the 6 week fowards
# Store 153 are going to sell about R$ 195,679.24 in the 6 week fowards
# Store 154 are going to sell about R$ 220,156.78 in the 6 week fowards
# Store 155 are going to sell about R$ 187,397.23 in the 6 week fowards
# Store 157 are going to sell about R$ 218,191.54 in the 6 week fowards
# Store 158 are going to sell about R$ 233,754.29 in the 6 week fowards
# Store 159 are going to sell about R$ 215,104.82 in the 6 week fowards
# Store 160 are going to sell about R$ 209,303.67 in the 6 week fowards
# Store 161 are going to sell about R$ 223,605.22 in the 6 week fowards
# Store 162 are going to sell about R$ 216,538.58 in the 6 week fowards
# Store 164 are going to sell about R$ 167,700.08 in the 6 week fowards
# Store 165 are going to sell about R$ 162,043.44 in the 6 week fowards
# Store 166 are going to sell about R$ 188,831.01 in the 6 week fowards
# Store 168 are going to sell about R$ 206,747.29 in the 6 week fowards
# Store 169 are going to sell about R$ 222,387.19 in the 6 week fowards
# Store 170 are going to sell about R$ 175,443.42 in the 6 week fowards
# Store 171 are going to sell about R$ 207,562.25 in the 6 week fowards
# Store 172 are going to sell about R$ 218,739.10 in the 6 week fowards
# Store 174 are going to sell about R$ 174,884.53 in the 6 week fowards
# Store 175 are going to sell about R$ 213,473.76 in the 6 week fowards
# Store 176 are going to sell about R$ 197,855.42 in the 6 week fowards
# Store 179 are going to sell about R$ 316,018.11 in the 6 week fowards
# Store 180 are going to sell about R$ 204,125.01 in the 6 week fowards
# Store 181 are going to sell about R$ 189,671.76 in the 6 week fowards
# Store 182 are going to sell about R$ 194,052.69 in the 6 week fowards
# Store 183 are going to sell about R$ 201,836.89 in the 6 week fowards
# Store 184 are going to sell about R$ 226,641.85 in the 6 week fowards
# Store 186 are going to sell about R$ 182,457.08 in the 6 week fowards
# Store 187 are going to sell about R$ 220,491.52 in the 6 week fowards
# Store 188 are going to sell about R$ 177,545.10 in the 6 week fowards
# Store 189 are going to sell about R$ 221,099.14 in the 6 week fowards
# Store 190 are going to sell about R$ 188,897.19 in the 6 week fowards
# Store 191 are going to sell about R$ 208,417.90 in the 6 week fowards
# Store 192 are going to sell about R$ 216,564.71 in the 6 week fowards
# Store 193 are going to sell about R$ 216,939.63 in the 6 week fowards
# Store 194 are going to sell about R$ 178,045.37 in the 6 week fowards
# Store 195 are going to sell about R$ 219,065.06 in the 6 week fowards
# Store 197 are going to sell about R$ 212,145.49 in the 6 week fowards
# Store 199 are going to sell about R$ 199,999.39 in the 6 week fowards
# Store 200 are going to sell about R$ 205,722.94 in the 6 week fowards
# Store 201 are going to sell about R$ 209,744.25 in the 6 week fowards
# Store 202 are going to sell about R$ 216,249.19 in the 6 week fowards
# Store 204 are going to sell about R$ 182,657.54 in the 6 week fowards
# Store 206 are going to sell about R$ 226,445.63 in the 6 week fowards
# Store 207 are going to sell about R$ 206,318.88 in the 6 week fowards
# Store 209 are going to sell about R$ 190,918.94 in the 6 week fowards
# Store 210 are going to sell about R$ 140,187.80 in the 6 week fowards
# Store 212 are going to sell about R$ 207,853.85 in the 6 week fowards
# Store 213 are going to sell about R$ 212,454.77 in the 6 week fowards
# Store 214 are going to sell about R$ 220,868.78 in the 6 week fowards
# Store 215 are going to sell about R$ 209,495.26 in the 6 week fowards
# Store 216 are going to sell about R$ 225,069.61 in the 6 week fowards
# Store 217 are going to sell about R$ 210,105.70 in the 6 week fowards
# Store 218 are going to sell about R$ 180,674.79 in the 6 week fowards
# Store 219 are going to sell about R$ 178,504.57 in the 6 week fowards
# Store 220 are going to sell about R$ 202,872.18 in the 6 week fowards
# Store 221 are going to sell about R$ 216,578.53 in the 6 week fowards
# Store 224 are going to sell about R$ 187,147.48 in the 6 week fowards
# Store 226 are going to sell about R$ 249,182.87 in the 6 week fowards
# Store 227 are going to sell about R$ 208,167.05 in the 6 week fowards
# Store 228 are going to sell about R$ 224,766.97 in the 6 week fowards
# Store 229 are going to sell about R$ 234,870.59 in the 6 week fowards
# Store 230 are going to sell about R$ 222,733.83 in the 6 week fowards
# Store 231 are going to sell about R$ 195,544.75 in the 6 week fowards
# Store 233 are going to sell about R$ 212,939.46 in the 6 week fowards
# Store 234 are going to sell about R$ 225,654.08 in the 6 week fowards
# Store 235 are going to sell about R$ 188,769.20 in the 6 week fowards
# Store 238 are going to sell about R$ 258,659.47 in the 6 week fowards
# Store 239 are going to sell about R$ 200,174.28 in the 6 week fowards
# Store 241 are going to sell about R$ 230,817.46 in the 6 week fowards
# Store 242 are going to sell about R$ 169,601.98 in the 6 week fowards
# Store 243 are going to sell about R$ 235,337.87 in the 6 week fowards
# Store 244 are going to sell about R$ 170,004.72 in the 6 week fowards
# Store 245 are going to sell about R$ 236,224.65 in the 6 week fowards
# Store 246 are going to sell about R$ 215,207.33 in the 6 week fowards
# Store 247 are going to sell about R$ 199,411.19 in the 6 week fowards
# Store 248 are going to sell about R$ 277,335.11 in the 6 week fowards
# Store 249 are going to sell about R$ 206,428.99 in the 6 week fowards
# Store 250 are going to sell about R$ 188,448.68 in the 6 week fowards
# Store 251 are going to sell about R$ 273,384.72 in the 6 week fowards
# Store 252 are going to sell about R$ 273,908.30 in the 6 week fowards
# Store 253 are going to sell about R$ 203,536.10 in the 6 week fowards
# Store 254 are going to sell about R$ 208,415.78 in the 6 week fowards
# Store 255 are going to sell about R$ 208,647.36 in the 6 week fowards
# Store 256 are going to sell about R$ 215,019.92 in the 6 week fowards
# Store 258 are going to sell about R$ 178,242.03 in the 6 week fowards
# Store 259 are going to sell about R$ 301,486.53 in the 6 week fowards
# Store 262 are going to sell about R$ 385,585.59 in the 6 week fowards
# Store 263 are going to sell about R$ 201,050.79 in the 6 week fowards
# Store 265 are going to sell about R$ 197,045.05 in the 6 week fowards
# Store 267 are going to sell about R$ 206,376.67 in the 6 week fowards
# Store 268 are going to sell about R$ 189,088.37 in the 6 week fowards
# Store 269 are going to sell about R$ 225,325.97 in the 6 week fowards
# Store 272 are going to sell about R$ 183,805.07 in the 6 week fowards
# Store 273 are going to sell about R$ 223,745.03 in the 6 week fowards
# Store 274 are going to sell about R$ 159,812.30 in the 6 week fowards
# Store 275 are going to sell about R$ 204,448.68 in the 6 week fowards
# Store 277 are going to sell about R$ 206,469.93 in the 6 week fowards
# Store 278 are going to sell about R$ 215,477.64 in the 6 week fowards
# Store 279 are going to sell about R$ 201,641.13 in the 6 week fowards
# Store 280 are going to sell about R$ 197,548.15 in the 6 week fowards
# Store 281 are going to sell about R$ 217,382.26 in the 6 week fowards
# Store 283 are going to sell about R$ 201,613.82 in the 6 week fowards
# Store 284 are going to sell about R$ 196,452.21 in the 6 week fowards
# Store 285 are going to sell about R$ 207,044.75 in the 6 week fowards
# Store 287 are going to sell about R$ 212,813.31 in the 6 week fowards
# Store 288 are going to sell about R$ 174,244.88 in the 6 week fowards
# Store 289 are going to sell about R$ 193,009.60 in the 6 week fowards
# Store 290 are going to sell about R$ 198,048.12 in the 6 week fowards
# Store 294 are going to sell about R$ 182,680.53 in the 6 week fowards
# Store 295 are going to sell about R$ 172,381.81 in the 6 week fowards
# Store 296 are going to sell about R$ 200,796.56 in the 6 week fowards
# Store 297 are going to sell about R$ 194,905.25 in the 6 week fowards
# Store 298 are going to sell about R$ 216,102.83 in the 6 week fowards
# Store 299 are going to sell about R$ 232,331.69 in the 6 week fowards
# Store 300 are going to sell about R$ 193,435.14 in the 6 week fowards
# Store 301 are going to sell about R$ 216,619.86 in the 6 week fowards
# Store 302 are going to sell about R$ 160,567.22 in the 6 week fowards
# Store 303 are going to sell about R$ 196,007.88 in the 6 week fowards
# Store 304 are going to sell about R$ 226,141.68 in the 6 week fowards
# Store 305 are going to sell about R$ 162,304.67 in the 6 week fowards
# Store 306 are going to sell about R$ 184,834.99 in the 6 week fowards
# Store 308 are going to sell about R$ 198,502.12 in the 6 week fowards
# Store 309 are going to sell about R$ 200,629.49 in the 6 week fowards
# Store 310 are going to sell about R$ 224,031.72 in the 6 week fowards
# Store 311 are going to sell about R$ 235,688.56 in the 6 week fowards
# Store 312 are going to sell about R$ 206,691.96 in the 6 week fowards
# Store 314 are going to sell about R$ 159,871.86 in the 6 week fowards
# Store 315 are going to sell about R$ 192,633.81 in the 6 week fowards
# Store 316 are going to sell about R$ 217,255.88 in the 6 week fowards
# Store 317 are going to sell about R$ 183,348.18 in the 6 week fowards
# Store 319 are going to sell about R$ 219,343.56 in the 6 week fowards
# Store 320 are going to sell about R$ 204,673.28 in the 6 week fowards
# Store 323 are going to sell about R$ 186,916.91 in the 6 week fowards
# Store 325 are going to sell about R$ 254,339.08 in the 6 week fowards
# Store 326 are going to sell about R$ 176,716.26 in the 6 week fowards
# Store 328 are going to sell about R$ 179,562.85 in the 6 week fowards
# Store 329 are going to sell about R$ 178,425.63 in the 6 week fowards
# Store 330 are going to sell about R$ 227,840.37 in the 6 week fowards
# Store 331 are going to sell about R$ 219,376.01 in the 6 week fowards
# Store 333 are going to sell about R$ 223,632.36 in the 6 week fowards
# Store 334 are going to sell about R$ 176,496.89 in the 6 week fowards
# Store 335 are going to sell about R$ 316,031.18 in the 6 week fowards
# Store 336 are going to sell about R$ 214,006.97 in the 6 week fowards
# Store 337 are going to sell about R$ 195,207.36 in the 6 week fowards
# Store 338 are going to sell about R$ 223,780.79 in the 6 week fowards
# Store 339 are going to sell about R$ 164,196.31 in the 6 week fowards
# Store 340 are going to sell about R$ 225,279.94 in the 6 week fowards
# Store 341 are going to sell about R$ 186,850.42 in the 6 week fowards
# Store 342 are going to sell about R$ 228,183.87 in the 6 week fowards
# Store 343 are going to sell about R$ 204,621.44 in the 6 week fowards
# Store 344 are going to sell about R$ 219,859.29 in the 6 week fowards
# Store 345 are going to sell about R$ 205,657.09 in the 6 week fowards
# Store 346 are going to sell about R$ 225,760.94 in the 6 week fowards
# Store 347 are going to sell about R$ 190,872.29 in the 6 week fowards
# Store 348 are going to sell about R$ 180,893.18 in the 6 week fowards
# Store 350 are going to sell about R$ 188,257.42 in the 6 week fowards
# Store 351 are going to sell about R$ 178,247.34 in the 6 week fowards
# Store 352 are going to sell about R$ 197,232.89 in the 6 week fowards
# Store 353 are going to sell about R$ 208,528.58 in the 6 week fowards
# Store 354 are going to sell about R$ 226,147.79 in the 6 week fowards
# Store 355 are going to sell about R$ 223,340.47 in the 6 week fowards
# Store 356 are going to sell about R$ 192,012.25 in the 6 week fowards
# Store 358 are going to sell about R$ 205,158.89 in the 6 week fowards
# Store 359 are going to sell about R$ 228,548.18 in the 6 week fowards
# Store 362 are going to sell about R$ 277,906.06 in the 6 week fowards
# Store 364 are going to sell about R$ 169,873.36 in the 6 week fowards
# Store 365 are going to sell about R$ 182,974.25 in the 6 week fowards
# Store 367 are going to sell about R$ 222,381.61 in the 6 week fowards
# Store 368 are going to sell about R$ 226,572.50 in the 6 week fowards
# Store 369 are going to sell about R$ 222,379.06 in the 6 week fowards
# Store 370 are going to sell about R$ 203,086.56 in the 6 week fowards
# Store 371 are going to sell about R$ 217,805.80 in the 6 week fowards
# Store 372 are going to sell about R$ 222,043.60 in the 6 week fowards
# Store 373 are going to sell about R$ 192,046.75 in the 6 week fowards
# Store 377 are going to sell about R$ 213,010.29 in the 6 week fowards
# Store 378 are going to sell about R$ 228,599.10 in the 6 week fowards
# Store 379 are going to sell about R$ 212,533.96 in the 6 week fowards
# Store 380 are going to sell about R$ 232,462.31 in the 6 week fowards
# Store 383 are going to sell about R$ 246,751.73 in the 6 week fowards
# Store 385 are going to sell about R$ 200,420.58 in the 6 week fowards
# Store 386 are going to sell about R$ 184,455.76 in the 6 week fowards
# Store 387 are going to sell about R$ 224,324.48 in the 6 week fowards
# Store 388 are going to sell about R$ 215,467.40 in the 6 week fowards
# Store 389 are going to sell about R$ 227,859.06 in the 6 week fowards
# Store 391 are going to sell about R$ 219,956.69 in the 6 week fowards
# Store 392 are going to sell about R$ 211,383.27 in the 6 week fowards
# Store 393 are going to sell about R$ 225,859.40 in the 6 week fowards
# Store 394 are going to sell about R$ 216,019.45 in the 6 week fowards
# Store 395 are going to sell about R$ 181,795.52 in the 6 week fowards
# Store 397 are going to sell about R$ 199,675.60 in the 6 week fowards
# Store 398 are going to sell about R$ 180,214.03 in the 6 week fowards
# Store 399 are going to sell about R$ 186,834.93 in the 6 week fowards
# Store 403 are going to sell about R$ 214,898.06 in the 6 week fowards
# Store 404 are going to sell about R$ 165,654.06 in the 6 week fowards
# Store 405 are going to sell about R$ 173,234.75 in the 6 week fowards
# Store 406 are going to sell about R$ 157,757.49 in the 6 week fowards
# Store 407 are going to sell about R$ 169,611.23 in the 6 week fowards
# Store 408 are going to sell about R$ 187,780.52 in the 6 week fowards
# Store 409 are going to sell about R$ 173,328.76 in the 6 week fowards
# Store 410 are going to sell about R$ 186,940.34 in the 6 week fowards
# Store 411 are going to sell about R$ 228,026.69 in the 6 week fowards
# Store 412 are going to sell about R$ 212,647.79 in the 6 week fowards
# Store 413 are going to sell about R$ 224,916.31 in the 6 week fowards
# Store 414 are going to sell about R$ 184,491.75 in the 6 week fowards
# Store 415 are going to sell about R$ 223,824.00 in the 6 week fowards
# Store 416 are going to sell about R$ 232,785.88 in the 6 week fowards
# Store 417 are going to sell about R$ 191,474.66 in the 6 week fowards
# Store 418 are going to sell about R$ 180,416.45 in the 6 week fowards
# Store 420 are going to sell about R$ 186,575.12 in the 6 week fowards
# Store 421 are going to sell about R$ 198,980.04 in the 6 week fowards
# Store 422 are going to sell about R$ 225,447.42 in the 6 week fowards
# Store 424 are going to sell about R$ 211,412.19 in the 6 week fowards
# Store 425 are going to sell about R$ 231,061.18 in the 6 week fowards
# Store 426 are going to sell about R$ 218,561.69 in the 6 week fowards
# Store 427 are going to sell about R$ 206,650.05 in the 6 week fowards
# Store 428 are going to sell about R$ 195,117.24 in the 6 week fowards
# Store 429 are going to sell about R$ 175,621.63 in the 6 week fowards
# Store 430 are going to sell about R$ 207,657.16 in the 6 week fowards
# Store 431 are going to sell about R$ 227,265.31 in the 6 week fowards
# Store 432 are going to sell about R$ 233,939.10 in the 6 week fowards
# Store 433 are going to sell about R$ 215,267.92 in the 6 week fowards
# Store 434 are going to sell about R$ 204,823.24 in the 6 week fowards
# Store 435 are going to sell about R$ 210,991.87 in the 6 week fowards
# Store 440 are going to sell about R$ 190,427.69 in the 6 week fowards
# Store 441 are going to sell about R$ 214,237.23 in the 6 week fowards
# Store 442 are going to sell about R$ 212,655.38 in the 6 week fowards
# Store 445 are going to sell about R$ 218,213.36 in the 6 week fowards
# Store 446 are going to sell about R$ 196,548.15 in the 6 week fowards
# Store 447 are going to sell about R$ 231,648.40 in the 6 week fowards
# Store 448 are going to sell about R$ 221,841.92 in the 6 week fowards
# Store 449 are going to sell about R$ 285,908.18 in the 6 week fowards
# Store 450 are going to sell about R$ 227,945.27 in the 6 week fowards
# Store 451 are going to sell about R$ 176,499.98 in the 6 week fowards
# Store 452 are going to sell about R$ 182,700.94 in the 6 week fowards
# Store 453 are going to sell about R$ 226,006.32 in the 6 week fowards
# Store 455 are going to sell about R$ 218,814.98 in the 6 week fowards
# Store 456 are going to sell about R$ 217,768.43 in the 6 week fowards
# Store 457 are going to sell about R$ 178,279.82 in the 6 week fowards
# Store 458 are going to sell about R$ 216,010.63 in the 6 week fowards
# Store 459 are going to sell about R$ 187,883.83 in the 6 week fowards
# Store 461 are going to sell about R$ 176,756.53 in the 6 week fowards
# Store 463 are going to sell about R$ 214,094.90 in the 6 week fowards
# Store 465 are going to sell about R$ 221,247.39 in the 6 week fowards
# Store 466 are going to sell about R$ 225,111.44 in the 6 week fowards
# Store 467 are going to sell about R$ 239,960.02 in the 6 week fowards
# Store 468 are going to sell about R$ 213,698.01 in the 6 week fowards
# Store 470 are going to sell about R$ 222,321.41 in the 6 week fowards
# Store 471 are going to sell about R$ 190,786.70 in the 6 week fowards
# Store 472 are going to sell about R$ 215,534.58 in the 6 week fowards
# Store 473 are going to sell about R$ 214,855.09 in the 6 week fowards
# Store 475 are going to sell about R$ 182,032.07 in the 6 week fowards
# Store 477 are going to sell about R$ 174,704.89 in the 6 week fowards
# Store 481 are going to sell about R$ 198,951.10 in the 6 week fowards
# Store 484 are going to sell about R$ 208,314.26 in the 6 week fowards
# Store 485 are going to sell about R$ 190,618.38 in the 6 week fowards
# Store 486 are going to sell about R$ 169,133.30 in the 6 week fowards
# Store 487 are going to sell about R$ 196,601.90 in the 6 week fowards
# Store 488 are going to sell about R$ 221,079.36 in the 6 week fowards
# Store 490 are going to sell about R$ 212,968.20 in the 6 week fowards
# Store 491 are going to sell about R$ 196,763.72 in the 6 week fowards
# Store 492 are going to sell about R$ 186,390.10 in the 6 week fowards
# Store 493 are going to sell about R$ 210,298.23 in the 6 week fowards
# Store 495 are going to sell about R$ 192,856.24 in the 6 week fowards
# Store 497 are going to sell about R$ 232,123.71 in the 6 week fowards
# Store 498 are going to sell about R$ 221,840.40 in the 6 week fowards
# Store 499 are going to sell about R$ 217,934.96 in the 6 week fowards
# Store 500 are going to sell about R$ 167,786.08 in the 6 week fowards
# Store 501 are going to sell about R$ 217,045.98 in the 6 week fowards
# Store 502 are going to sell about R$ 229,244.10 in the 6 week fowards
# Store 504 are going to sell about R$ 261,094.49 in the 6 week fowards
# Store 505 are going to sell about R$ 233,527.41 in the 6 week fowards
# Store 506 are going to sell about R$ 198,312.87 in the 6 week fowards
# Store 507 are going to sell about R$ 236,361.61 in the 6 week fowards
# Store 508 are going to sell about R$ 217,710.48 in the 6 week fowards
# Store 509 are going to sell about R$ 193,417.79 in the 6 week fowards
# Store 510 are going to sell about R$ 226,231.59 in the 6 week fowards
# Store 511 are going to sell about R$ 202,384.42 in the 6 week fowards
# Store 512 are going to sell about R$ 213,537.36 in the 6 week fowards
# Store 514 are going to sell about R$ 187,790.24 in the 6 week fowards
# Store 515 are going to sell about R$ 223,948.77 in the 6 week fowards
# Store 516 are going to sell about R$ 210,815.04 in the 6 week fowards
# Store 517 are going to sell about R$ 228,646.78 in the 6 week fowards
# Store 518 are going to sell about R$ 213,685.26 in the 6 week fowards
# Store 519 are going to sell about R$ 176,451.47 in the 6 week fowards
# Store 520 are going to sell about R$ 192,619.38 in the 6 week fowards
# Store 521 are going to sell about R$ 176,014.16 in the 6 week fowards
# Store 522 are going to sell about R$ 219,297.16 in the 6 week fowards
# Store 524 are going to sell about R$ 226,878.95 in the 6 week fowards
# Store 527 are going to sell about R$ 231,397.30 in the 6 week fowards
# Store 528 are going to sell about R$ 274,487.04 in the 6 week fowards
# Store 529 are going to sell about R$ 215,479.86 in the 6 week fowards
# Store 530 are going to sell about R$ 225,252.03 in the 6 week fowards
# Store 531 are going to sell about R$ 226,690.10 in the 6 week fowards
# Store 532 are going to sell about R$ 251,936.36 in the 6 week fowards
# Store 533 are going to sell about R$ 225,428.97 in the 6 week fowards
# Store 534 are going to sell about R$ 183,992.69 in the 6 week fowards
# Store 535 are going to sell about R$ 200,361.28 in the 6 week fowards
# Store 536 are going to sell about R$ 199,003.75 in the 6 week fowards
# Store 537 are going to sell about R$ 165,352.75 in the 6 week fowards
# Store 538 are going to sell about R$ 184,911.63 in the 6 week fowards
# Store 539 are going to sell about R$ 225,038.38 in the 6 week fowards
# Store 540 are going to sell about R$ 196,948.49 in the 6 week fowards
# Store 541 are going to sell about R$ 275,728.07 in the 6 week fowards
# Store 542 are going to sell about R$ 173,989.42 in the 6 week fowards
# Store 543 are going to sell about R$ 181,350.66 in the 6 week fowards
# Store 545 are going to sell about R$ 210,299.17 in the 6 week fowards
# Store 547 are going to sell about R$ 204,623.88 in the 6 week fowards
# Store 548 are going to sell about R$ 211,661.05 in the 6 week fowards
# Store 549 are going to sell about R$ 225,092.28 in the 6 week fowards
# Store 550 are going to sell about R$ 203,466.80 in the 6 week fowards
# Store 551 are going to sell about R$ 222,304.94 in the 6 week fowards
# Store 552 are going to sell about R$ 200,735.43 in the 6 week fowards
# Store 553 are going to sell about R$ 184,827.55 in the 6 week fowards
# Store 554 are going to sell about R$ 236,944.69 in the 6 week fowards
# Store 555 are going to sell about R$ 157,501.90 in the 6 week fowards
# Store 557 are going to sell about R$ 212,147.67 in the 6 week fowards
# Store 558 are going to sell about R$ 175,961.61 in the 6 week fowards
# Store 561 are going to sell about R$ 208,239.08 in the 6 week fowards
# Store 562 are going to sell about R$ 373,517.66 in the 6 week fowards
# Store 563 are going to sell about R$ 199,241.68 in the 6 week fowards
# Store 564 are going to sell about R$ 184,689.69 in the 6 week fowards
# Store 565 are going to sell about R$ 194,233.20 in the 6 week fowards
# Store 566 are going to sell about R$ 173,051.79 in the 6 week fowards
# Store 567 are going to sell about R$ 178,530.36 in the 6 week fowards
# Store 568 are going to sell about R$ 180,775.03 in the 6 week fowards
# Store 570 are going to sell about R$ 174,385.73 in the 6 week fowards
# Store 571 are going to sell about R$ 211,913.11 in the 6 week fowards
# Store 572 are going to sell about R$ 227,610.55 in the 6 week fowards
# Store 573 are going to sell about R$ 155,401.26 in the 6 week fowards
# Store 574 are going to sell about R$ 223,241.67 in the 6 week fowards
# Store 575 are going to sell about R$ 176,888.99 in the 6 week fowards
# Store 577 are going to sell about R$ 189,535.00 in the 6 week fowards
# Store 578 are going to sell about R$ 246,394.78 in the 6 week fowards
# Store 579 are going to sell about R$ 206,553.62 in the 6 week fowards
# Store 580 are going to sell about R$ 200,519.89 in the 6 week fowards
# Store 581 are going to sell about R$ 193,332.19 in the 6 week fowards
# Store 582 are going to sell about R$ 215,535.11 in the 6 week fowards
# Store 584 are going to sell about R$ 184,065.73 in the 6 week fowards
# Store 585 are going to sell about R$ 240,494.70 in the 6 week fowards
# Store 586 are going to sell about R$ 195,743.09 in the 6 week fowards
# Store 587 are going to sell about R$ 247,285.76 in the 6 week fowards
# Store 588 are going to sell about R$ 215,819.36 in the 6 week fowards
# Store 589 are going to sell about R$ 219,427.25 in the 6 week fowards
# Store 590 are going to sell about R$ 174,648.42 in the 6 week fowards
# Store 591 are going to sell about R$ 194,345.24 in the 6 week fowards
# Store 592 are going to sell about R$ 182,516.43 in the 6 week fowards
# Store 593 are going to sell about R$ 206,551.80 in the 6 week fowards
# Store 597 are going to sell about R$ 179,547.30 in the 6 week fowards
# Store 598 are going to sell about R$ 181,448.54 in the 6 week fowards
# Store 600 are going to sell about R$ 225,171.12 in the 6 week fowards
# Store 601 are going to sell about R$ 189,965.26 in the 6 week fowards
# Store 602 are going to sell about R$ 174,346.56 in the 6 week fowards
# Store 603 are going to sell about R$ 241,785.87 in the 6 week fowards
# Store 604 are going to sell about R$ 208,575.40 in the 6 week fowards
# Store 605 are going to sell about R$ 198,167.91 in the 6 week fowards
# Store 610 are going to sell about R$ 190,327.30 in the 6 week fowards
# Store 611 are going to sell about R$ 181,430.19 in the 6 week fowards
# Store 612 are going to sell about R$ 211,054.17 in the 6 week fowards
# Store 615 are going to sell about R$ 215,380.57 in the 6 week fowards
# Store 616 are going to sell about R$ 212,261.21 in the 6 week fowards
# Store 618 are going to sell about R$ 221,848.47 in the 6 week fowards
# Store 619 are going to sell about R$ 171,155.71 in the 6 week fowards
# Store 620 are going to sell about R$ 213,022.69 in the 6 week fowards
# Store 621 are going to sell about R$ 182,291.55 in the 6 week fowards
# Store 622 are going to sell about R$ 131,669.29 in the 6 week fowards
# Store 623 are going to sell about R$ 197,873.76 in the 6 week fowards
# Store 624 are going to sell about R$ 218,807.13 in the 6 week fowards
# Store 625 are going to sell about R$ 173,289.34 in the 6 week fowards
# Store 627 are going to sell about R$ 218,893.07 in the 6 week fowards
# Store 628 are going to sell about R$ 225,800.94 in the 6 week fowards
# Store 629 are going to sell about R$ 210,161.93 in the 6 week fowards
# Store 631 are going to sell about R$ 194,807.36 in the 6 week fowards
# Store 632 are going to sell about R$ 190,226.92 in the 6 week fowards
# Store 633 are going to sell about R$ 186,474.73 in the 6 week fowards
# Store 636 are going to sell about R$ 175,890.30 in the 6 week fowards
# Store 637 are going to sell about R$ 226,594.73 in the 6 week fowards
# Store 638 are going to sell about R$ 190,065.34 in the 6 week fowards
# Store 639 are going to sell about R$ 180,608.15 in the 6 week fowards
# Store 640 are going to sell about R$ 228,134.84 in the 6 week fowards
# Store 641 are going to sell about R$ 135,920.10 in the 6 week fowards
# Store 642 are going to sell about R$ 208,233.46 in the 6 week fowards
# Store 643 are going to sell about R$ 207,536.39 in the 6 week fowards
# Store 644 are going to sell about R$ 209,576.52 in the 6 week fowards
# Store 645 are going to sell about R$ 237,551.89 in the 6 week fowards
# Store 646 are going to sell about R$ 212,078.16 in the 6 week fowards
# Store 647 are going to sell about R$ 220,340.75 in the 6 week fowards
# Store 650 are going to sell about R$ 188,931.08 in the 6 week fowards
# Store 651 are going to sell about R$ 217,420.73 in the 6 week fowards
# Store 653 are going to sell about R$ 205,228.04 in the 6 week fowards
# Store 655 are going to sell about R$ 185,192.83 in the 6 week fowards
# Store 656 are going to sell about R$ 206,006.47 in the 6 week fowards
# Store 657 are going to sell about R$ 187,009.24 in the 6 week fowards
# Store 658 are going to sell about R$ 234,298.85 in the 6 week fowards
# Store 659 are going to sell about R$ 207,978.34 in the 6 week fowards
# Store 660 are going to sell about R$ 178,056.61 in the 6 week fowards
# Store 661 are going to sell about R$ 227,078.23 in the 6 week fowards
# Store 662 are going to sell about R$ 221,739.93 in the 6 week fowards
# Store 663 are going to sell about R$ 217,085.76 in the 6 week fowards
# Store 665 are going to sell about R$ 211,969.85 in the 6 week fowards
# Store 666 are going to sell about R$ 196,429.28 in the 6 week fowards
# Store 667 are going to sell about R$ 225,191.39 in the 6 week fowards
# Store 669 are going to sell about R$ 177,013.44 in the 6 week fowards
# Store 670 are going to sell about R$ 178,425.37 in the 6 week fowards
# Store 671 are going to sell about R$ 208,947.70 in the 6 week fowards
# Store 673 are going to sell about R$ 184,421.11 in the 6 week fowards
# Store 674 are going to sell about R$ 187,089.65 in the 6 week fowards
# Store 675 are going to sell about R$ 174,379.51 in the 6 week fowards
# Store 676 are going to sell about R$ 315,142.37 in the 6 week fowards
# Store 677 are going to sell about R$ 182,766.66 in the 6 week fowards
# Store 678 are going to sell about R$ 191,507.30 in the 6 week fowards
# Store 680 are going to sell about R$ 207,196.32 in the 6 week fowards
# Store 681 are going to sell about R$ 153,217.47 in the 6 week fowards
# Store 684 are going to sell about R$ 188,654.14 in the 6 week fowards
# Store 685 are going to sell about R$ 185,633.39 in the 6 week fowards
# Store 687 are going to sell about R$ 229,583.53 in the 6 week fowards
# Store 689 are going to sell about R$ 200,174.16 in the 6 week fowards
# Store 690 are going to sell about R$ 218,321.62 in the 6 week fowards
# Store 691 are going to sell about R$ 219,731.59 in the 6 week fowards
# Store 692 are going to sell about R$ 186,095.97 in the 6 week fowards
# Store 693 are going to sell about R$ 242,080.25 in the 6 week fowards
# Store 694 are going to sell about R$ 283,386.48 in the 6 week fowards
# Store 695 are going to sell about R$ 164,329.04 in the 6 week fowards
# Store 696 are going to sell about R$ 249,727.44 in the 6 week fowards
# Store 697 are going to sell about R$ 198,393.55 in the 6 week fowards
# Store 699 are going to sell about R$ 218,498.08 in the 6 week fowards
# Store 700 are going to sell about R$ 165,292.64 in the 6 week fowards
# Store 701 are going to sell about R$ 176,975.48 in the 6 week fowards
# Store 702 are going to sell about R$ 172,255.41 in the 6 week fowards
# Store 703 are going to sell about R$ 155,657.14 in the 6 week fowards
# Store 705 are going to sell about R$ 197,514.81 in the 6 week fowards
# Store 706 are going to sell about R$ 200,088.09 in the 6 week fowards
# Store 707 are going to sell about R$ 238,280.32 in the 6 week fowards
# Store 710 are going to sell about R$ 170,734.13 in the 6 week fowards
# Store 711 are going to sell about R$ 206,321.00 in the 6 week fowards
# Store 712 are going to sell about R$ 185,024.30 in the 6 week fowards
# Store 713 are going to sell about R$ 224,316.94 in the 6 week fowards
# Store 714 are going to sell about R$ 147,761.79 in the 6 week fowards
# Store 716 are going to sell about R$ 177,648.04 in the 6 week fowards
# Store 717 are going to sell about R$ 271,782.42 in the 6 week fowards
# Store 718 are going to sell about R$ 220,343.04 in the 6 week fowards
# Store 719 are going to sell about R$ 207,567.43 in the 6 week fowards
# Store 720 are going to sell about R$ 189,457.35 in the 6 week fowards
# Store 721 are going to sell about R$ 203,898.78 in the 6 week fowards
# Store 722 are going to sell about R$ 222,959.01 in the 6 week fowards
# Store 723 are going to sell about R$ 181,701.56 in the 6 week fowards
# Store 724 are going to sell about R$ 226,762.88 in the 6 week fowards
# Store 725 are going to sell about R$ 217,641.96 in the 6 week fowards
# Store 727 are going to sell about R$ 200,425.14 in the 6 week fowards
# Store 728 are going to sell about R$ 189,127.39 in the 6 week fowards
# Store 729 are going to sell about R$ 224,485.54 in the 6 week fowards
# Store 731 are going to sell about R$ 207,083.92 in the 6 week fowards
# Store 732 are going to sell about R$ 218,793.58 in the 6 week fowards
# Store 733 are going to sell about R$ 375,233.99 in the 6 week fowards
# Store 734 are going to sell about R$ 210,190.15 in the 6 week fowards
# Store 736 are going to sell about R$ 208,862.23 in the 6 week fowards
# Store 737 are going to sell about R$ 186,859.93 in the 6 week fowards
# Store 738 are going to sell about R$ 218,314.37 in the 6 week fowards
# Store 739 are going to sell about R$ 215,277.78 in the 6 week fowards
# Store 740 are going to sell about R$ 212,940.09 in the 6 week fowards
# Store 741 are going to sell about R$ 219,416.41 in the 6 week fowards
# Store 742 are going to sell about R$ 228,837.54 in the 6 week fowards
# Store 744 are going to sell about R$ 190,907.24 in the 6 week fowards
# Store 746 are going to sell about R$ 208,976.26 in the 6 week fowards
# Store 748 are going to sell about R$ 179,270.29 in the 6 week fowards
# Store 749 are going to sell about R$ 193,772.95 in the 6 week fowards
# Store 750 are going to sell about R$ 181,419.06 in the 6 week fowards
# Store 751 are going to sell about R$ 217,338.93 in the 6 week fowards
# Store 752 are going to sell about R$ 170,434.20 in the 6 week fowards
# Store 753 are going to sell about R$ 240,430.78 in the 6 week fowards
# Store 756 are going to sell about R$ 304,676.68 in the 6 week fowards
# Store 757 are going to sell about R$ 228,206.29 in the 6 week fowards
# Store 758 are going to sell about R$ 221,051.50 in the 6 week fowards
# Store 759 are going to sell about R$ 180,226.40 in the 6 week fowards
# Store 762 are going to sell about R$ 157,509.00 in the 6 week fowards
# Store 763 are going to sell about R$ 201,769.46 in the 6 week fowards
# Store 764 are going to sell about R$ 122,343.64 in the 6 week fowards
# Store 765 are going to sell about R$ 242,505.41 in the 6 week fowards
# Store 766 are going to sell about R$ 211,047.01 in the 6 week fowards
# Store 767 are going to sell about R$ 208,087.07 in the 6 week fowards
# Store 768 are going to sell about R$ 233,381.51 in the 6 week fowards
# Store 769 are going to sell about R$ 300,708.80 in the 6 week fowards
# Store 770 are going to sell about R$ 205,589.69 in the 6 week fowards
# Store 771 are going to sell about R$ 195,239.63 in the 6 week fowards
# Store 772 are going to sell about R$ 206,779.55 in the 6 week fowards
# Store 773 are going to sell about R$ 220,357.86 in the 6 week fowards
# Store 774 are going to sell about R$ 252,753.11 in the 6 week fowards
# Store 775 are going to sell about R$ 207,149.26 in the 6 week fowards
# Store 776 are going to sell about R$ 177,843.41 in the 6 week fowards
# Store 777 are going to sell about R$ 138,201.97 in the 6 week fowards
# Store 778 are going to sell about R$ 205,931.30 in the 6 week fowards
# Store 782 are going to sell about R$ 178,065.33 in the 6 week fowards
# Store 784 are going to sell about R$ 181,365.55 in the 6 week fowards
# Store 785 are going to sell about R$ 176,376.41 in the 6 week fowards
# Store 789 are going to sell about R$ 200,902.21 in the 6 week fowards
# Store 790 are going to sell about R$ 211,535.91 in the 6 week fowards
# Store 791 are going to sell about R$ 204,102.49 in the 6 week fowards
# Store 792 are going to sell about R$ 196,476.23 in the 6 week fowards
# Store 793 are going to sell about R$ 195,618.16 in the 6 week fowards
# Store 795 are going to sell about R$ 193,643.12 in the 6 week fowards
# Store 796 are going to sell about R$ 218,515.59 in the 6 week fowards
# Store 797 are going to sell about R$ 184,640.21 in the 6 week fowards
# Store 799 are going to sell about R$ 229,053.00 in the 6 week fowards
# Store 800 are going to sell about R$ 216,273.04 in the 6 week fowards
# Store 801 are going to sell about R$ 166,199.04 in the 6 week fowards
# Store 802 are going to sell about R$ 209,276.27 in the 6 week fowards
# Store 803 are going to sell about R$ 199,581.06 in the 6 week fowards
# Store 804 are going to sell about R$ 167,159.60 in the 6 week fowards
# Store 805 are going to sell about R$ 156,930.28 in the 6 week fowards
# Store 806 are going to sell about R$ 219,252.27 in the 6 week fowards
# Store 807 are going to sell about R$ 216,915.36 in the 6 week fowards
# Store 809 are going to sell about R$ 218,837.44 in the 6 week fowards
# Store 810 are going to sell about R$ 212,876.21 in the 6 week fowards
# Store 811 are going to sell about R$ 217,037.43 in the 6 week fowards
# Store 813 are going to sell about R$ 191,996.00 in the 6 week fowards
# Store 815 are going to sell about R$ 234,131.44 in the 6 week fowards
# Store 816 are going to sell about R$ 279,522.83 in the 6 week fowards
# Store 818 are going to sell about R$ 194,732.27 in the 6 week fowards
# Store 819 are going to sell about R$ 225,339.67 in the 6 week fowards
# Store 820 are going to sell about R$ 222,812.91 in the 6 week fowards
# Store 822 are going to sell about R$ 305,494.21 in the 6 week fowards
# Store 823 are going to sell about R$ 207,939.25 in the 6 week fowards
# Store 824 are going to sell about R$ 197,957.08 in the 6 week fowards
# Store 825 are going to sell about R$ 235,752.49 in the 6 week fowards
# Store 826 are going to sell about R$ 220,731.07 in the 6 week fowards
# Store 829 are going to sell about R$ 219,893.42 in the 6 week fowards
# Store 831 are going to sell about R$ 212,399.07 in the 6 week fowards
# Store 832 are going to sell about R$ 191,735.39 in the 6 week fowards
# Store 833 are going to sell about R$ 193,321.24 in the 6 week fowards
# Store 835 are going to sell about R$ 180,885.16 in the 6 week fowards
# Store 837 are going to sell about R$ 204,966.19 in the 6 week fowards
# Store 840 are going to sell about R$ 210,787.39 in the 6 week fowards
# Store 842 are going to sell about R$ 231,331.78 in the 6 week fowards
# Store 844 are going to sell about R$ 173,515.04 in the 6 week fowards
# Store 845 are going to sell about R$ 174,577.41 in the 6 week fowards
# Store 846 are going to sell about R$ 236,348.14 in the 6 week fowards
# Store 847 are going to sell about R$ 213,357.45 in the 6 week fowards
# Store 848 are going to sell about R$ 252,508.40 in the 6 week fowards
# Store 849 are going to sell about R$ 223,666.23 in the 6 week fowards
# Store 850 are going to sell about R$ 173,396.10 in the 6 week fowards
# Store 851 are going to sell about R$ 201,330.60 in the 6 week fowards
# Store 852 are going to sell about R$ 172,015.59 in the 6 week fowards
# Store 853 are going to sell about R$ 193,239.24 in the 6 week fowards
# Store 855 are going to sell about R$ 179,918.12 in the 6 week fowards
# Store 856 are going to sell about R$ 189,559.94 in the 6 week fowards
# Store 857 are going to sell about R$ 207,219.85 in the 6 week fowards
# Store 858 are going to sell about R$ 172,977.73 in the 6 week fowards
# Store 859 are going to sell about R$ 223,941.15 in the 6 week fowards
# Store 860 are going to sell about R$ 208,676.20 in the 6 week fowards
# Store 861 are going to sell about R$ 173,047.83 in the 6 week fowards
# Store 862 are going to sell about R$ 219,797.98 in the 6 week fowards
# Store 863 are going to sell about R$ 224,134.90 in the 6 week fowards
# Store 864 are going to sell about R$ 174,128.15 in the 6 week fowards
# Store 865 are going to sell about R$ 229,675.03 in the 6 week fowards
# Store 866 are going to sell about R$ 181,824.10 in the 6 week fowards
# Store 867 are going to sell about R$ 240,119.93 in the 6 week fowards
# Store 868 are going to sell about R$ 228,354.68 in the 6 week fowards
# Store 871 are going to sell about R$ 220,901.48 in the 6 week fowards
# Store 872 are going to sell about R$ 222,388.19 in the 6 week fowards
# Store 874 are going to sell about R$ 201,600.70 in the 6 week fowards
# Store 875 are going to sell about R$ 181,106.01 in the 6 week fowards
# Store 877 are going to sell about R$ 198,614.99 in the 6 week fowards
# Store 879 are going to sell about R$ 115,404.22 in the 6 week fowards
# Store 880 are going to sell about R$ 229,101.09 in the 6 week fowards
# Store 881 are going to sell about R$ 186,636.29 in the 6 week fowards
# Store 882 are going to sell about R$ 202,051.73 in the 6 week fowards
# Store 883 are going to sell about R$ 183,395.49 in the 6 week fowards
# Store 884 are going to sell about R$ 221,563.13 in the 6 week fowards
# Store 885 are going to sell about R$ 203,089.32 in the 6 week fowards
# Store 886 are going to sell about R$ 208,925.91 in the 6 week fowards
# Store 887 are going to sell about R$ 210,283.91 in the 6 week fowards
# Store 888 are going to sell about R$ 196,705.60 in the 6 week fowards
# Store 890 are going to sell about R$ 178,477.99 in the 6 week fowards
# Store 891 are going to sell about R$ 229,824.21 in the 6 week fowards
# Store 893 are going to sell about R$ 212,049.58 in the 6 week fowards
# Store 894 are going to sell about R$ 181,728.72 in the 6 week fowards
# Store 895 are going to sell about R$ 229,564.96 in the 6 week fowards
# Store 896 are going to sell about R$ 191,274.19 in the 6 week fowards
# Store 897 are going to sell about R$ 141,460.20 in the 6 week fowards
# Store 900 are going to sell about R$ 198,986.58 in the 6 week fowards
# Store 901 are going to sell about R$ 224,517.35 in the 6 week fowards
# Store 902 are going to sell about R$ 249,761.69 in the 6 week fowards
# Store 903 are going to sell about R$ 217,365.57 in the 6 week fowards
# Store 904 are going to sell about R$ 218,289.51 in the 6 week fowards
# Store 905 are going to sell about R$ 204,384.83 in the 6 week fowards
# Store 906 are going to sell about R$ 206,583.78 in the 6 week fowards
# Store 907 are going to sell about R$ 205,678.09 in the 6 week fowards
# Store 908 are going to sell about R$ 171,803.74 in the 6 week fowards
# Store 909 are going to sell about R$ 227,369.96 in the 6 week fowards
# Store 911 are going to sell about R$ 210,140.92 in the 6 week fowards
# Store 912 are going to sell about R$ 220,522.91 in the 6 week fowards
# Store 913 are going to sell about R$ 218,952.96 in the 6 week fowards
# Store 914 are going to sell about R$ 199,497.35 in the 6 week fowards
# Store 915 are going to sell about R$ 214,402.79 in the 6 week fowards
# Store 916 are going to sell about R$ 181,434.81 in the 6 week fowards
# Store 917 are going to sell about R$ 198,986.08 in the 6 week fowards
# Store 919 are going to sell about R$ 174,802.11 in the 6 week fowards
# Store 920 are going to sell about R$ 188,051.02 in the 6 week fowards
# Store 922 are going to sell about R$ 205,340.56 in the 6 week fowards
# Store 924 are going to sell about R$ 180,606.06 in the 6 week fowards
# Store 925 are going to sell about R$ 234,761.17 in the 6 week fowards
# Store 926 are going to sell about R$ 214,558.25 in the 6 week fowards
# Store 927 are going to sell about R$ 223,125.08 in the 6 week fowards
# Store 928 are going to sell about R$ 201,096.53 in the 6 week fowards
# Store 929 are going to sell about R$ 225,678.88 in the 6 week fowards
# Store 930 are going to sell about R$ 218,847.15 in the 6 week fowards
# Store 931 are going to sell about R$ 176,034.23 in the 6 week fowards
# Store 932 are going to sell about R$ 199,980.22 in the 6 week fowards
# Store 934 are going to sell about R$ 208,705.10 in the 6 week fowards
# Store 935 are going to sell about R$ 227,625.46 in the 6 week fowards
# Store 936 are going to sell about R$ 202,933.15 in the 6 week fowards
# Store 937 are going to sell about R$ 204,223.16 in the 6 week fowards
# Store 938 are going to sell about R$ 199,717.97 in the 6 week fowards
# Store 939 are going to sell about R$ 215,481.89 in the 6 week fowards
# Store 941 are going to sell about R$ 157,234.80 in the 6 week fowards
# Store 942 are going to sell about R$ 214,017.44 in the 6 week fowards
# Store 943 are going to sell about R$ 210,085.57 in the 6 week fowards
# Store 944 are going to sell about R$ 221,116.10 in the 6 week fowards
# Store 945 are going to sell about R$ 213,186.34 in the 6 week fowards
# Store 946 are going to sell about R$ 175,901.68 in the 6 week fowards
# Store 947 are going to sell about R$ 223,669.17 in the 6 week fowards
# Store 948 are going to sell about R$ 322,876.67 in the 6 week fowards
# Store 950 are going to sell about R$ 184,413.57 in the 6 week fowards
# Store 951 are going to sell about R$ 216,030.62 in the 6 week fowards
# Store 952 are going to sell about R$ 215,277.53 in the 6 week fowards
# Store 954 are going to sell about R$ 216,661.50 in the 6 week fowards
# Store 955 are going to sell about R$ 171,262.97 in the 6 week fowards
# Store 956 are going to sell about R$ 169,645.29 in the 6 week fowards
# Store 960 are going to sell about R$ 193,438.96 in the 6 week fowards
# Store 961 are going to sell about R$ 215,825.23 in the 6 week fowards
# Store 962 are going to sell about R$ 206,677.14 in the 6 week fowards
# Store 964 are going to sell about R$ 201,183.40 in the 6 week fowards
# Store 965 are going to sell about R$ 191,657.23 in the 6 week fowards
# Store 966 are going to sell about R$ 199,785.99 in the 6 week fowards
# Store 967 are going to sell about R$ 192,968.01 in the 6 week fowards
# Store 969 are going to sell about R$ 152,731.46 in the 6 week fowards
# Store 970 are going to sell about R$ 161,724.89 in the 6 week fowards
# Store 973 are going to sell about R$ 226,663.46 in the 6 week fowards
# Store 974 are going to sell about R$ 214,153.98 in the 6 week fowards
# Store 975 are going to sell about R$ 218,190.98 in the 6 week fowards
# Store 976 are going to sell about R$ 213,649.02 in the 6 week fowards
# Store 977 are going to sell about R$ 210,357.95 in the 6 week fowards
# Store 980 are going to sell about R$ 195,555.90 in the 6 week fowards
# Store 983 are going to sell about R$ 207,982.69 in the 6 week fowards
# Store 984 are going to sell about R$ 230,170.10 in the 6 week fowards
# Store 985 are going to sell about R$ 246,018.17 in the 6 week fowards
# Store 986 are going to sell about R$ 181,875.43 in the 6 week fowards
# Store 988 are going to sell about R$ 170,154.22 in the 6 week fowards
# Store 989 are going to sell about R$ 174,608.05 in the 6 week fowards
# Store 991 are going to sell about R$ 216,038.41 in the 6 week fowards
# Store 992 are going to sell about R$ 191,013.71 in the 6 week fowards
# Store 994 are going to sell about R$ 166,042.99 in the 6 week fowards
# Store 997 are going to sell about R$ 196,024.94 in the 6 week fowards
# Store 998 are going to sell about R$ 163,495.61 in the 6 week fowards
# Store 1000 are going to sell about R$ 222,822.97 in the 6 week fowards
# Store 1003 are going to sell about R$ 175,182.21 in the 6 week fowards
# Store 1004 are going to sell about R$ 184,410.49 in the 6 week fowards
# Store 1005 are going to sell about R$ 210,454.74 in the 6 week fowards
# Store 1007 are going to sell about R$ 219,012.54 in the 6 week fowards
# Store 1008 are going to sell about R$ 184,903.59 in the 6 week fowards
# Store 1009 are going to sell about R$ 173,658.18 in the 6 week fowards
# Store 1010 are going to sell about R$ 220,680.07 in the 6 week fowards
# Store 1011 are going to sell about R$ 274,350.60 in the 6 week fowards
# Store 1012 are going to sell about R$ 205,844.85 in the 6 week fowards
# Store 1013 are going to sell about R$ 164,857.77 in the 6 week fowards
# Store 1014 are going to sell about R$ 201,901.11 in the 6 week fowards
# Store 1015 are going to sell about R$ 198,294.81 in the 6 week fowards
# Store 1016 are going to sell about R$ 238,690.18 in the 6 week fowards
# Store 1019 are going to sell about R$ 214,764.82 in the 6 week fowards
# Store 1020 are going to sell about R$ 210,914.91 in the 6 week fowards
# Store 1022 are going to sell about R$ 241,057.48 in the 6 week fowards
# Store 1024 are going to sell about R$ 199,946.16 in the 6 week fowards
# Store 1025 are going to sell about R$ 197,876.32 in the 6 week fowards
# Store 1026 are going to sell about R$ 255,737.85 in the 6 week fowards
# Store 1027 are going to sell about R$ 279,008.47 in the 6 week fowards
# Store 1028 are going to sell about R$ 188,594.23 in the 6 week fowards
# Store 1031 are going to sell about R$ 199,491.00 in the 6 week fowards
# Store 1036 are going to sell about R$ 194,694.33 in the 6 week fowards
# Store 1037 are going to sell about R$ 190,869.17 in the 6 week fowards
# Store 1038 are going to sell about R$ 201,202.02 in the 6 week fowards
# Store 1039 are going to sell about R$ 200,972.59 in the 6 week fowards
# Store 1040 are going to sell about R$ 217,332.08 in the 6 week fowards
# Store 1041 are going to sell about R$ 213,660.18 in the 6 week fowards
# Store 1042 are going to sell about R$ 171,497.43 in the 6 week fowards
# Store 1044 are going to sell about R$ 208,340.79 in the 6 week fowards
# Store 1045 are going to sell about R$ 229,187.58 in the 6 week fowards
# Store 1047 are going to sell about R$ 176,494.21 in the 6 week fowards
# Store 1048 are going to sell about R$ 196,066.25 in the 6 week fowards
# Store 1049 are going to sell about R$ 208,255.76 in the 6 week fowards
# Store 1050 are going to sell about R$ 209,069.01 in the 6 week fowards
# Store 1051 are going to sell about R$ 190,146.05 in the 6 week fowards
# Store 1052 are going to sell about R$ 200,792.61 in the 6 week fowards
# Store 1053 are going to sell about R$ 231,290.34 in the 6 week fowards
# Store 1054 are going to sell about R$ 191,467.04 in the 6 week fowards
# Store 1056 are going to sell about R$ 190,934.10 in the 6 week fowards
# Store 1057 are going to sell about R$ 218,943.67 in the 6 week fowards
# Store 1058 are going to sell about R$ 198,652.91 in the 6 week fowards
# Store 1059 are going to sell about R$ 225,119.43 in the 6 week fowards
# Store 1060 are going to sell about R$ 204,377.81 in the 6 week fowards
# Store 1061 are going to sell about R$ 229,659.82 in the 6 week fowards
# Store 1062 are going to sell about R$ 182,151.87 in the 6 week fowards
# Store 1063 are going to sell about R$ 219,145.80 in the 6 week fowards
# Store 1064 are going to sell about R$ 242,321.93 in the 6 week fowards
# Store 1065 are going to sell about R$ 170,230.79 in the 6 week fowards
# Store 1066 are going to sell about R$ 233,527.08 in the 6 week fowards
# Store 1067 are going to sell about R$ 211,703.45 in the 6 week fowards
# Store 1068 are going to sell about R$ 173,181.33 in the 6 week fowards
# Store 1070 are going to sell about R$ 230,656.14 in the 6 week fowards
# Store 1071 are going to sell about R$ 181,653.54 in the 6 week fowards
# Store 1072 are going to sell about R$ 198,988.43 in the 6 week fowards
# Store 1073 are going to sell about R$ 203,356.31 in the 6 week fowards
# Store 1076 are going to sell about R$ 148,886.19 in the 6 week fowards
# Store 1077 are going to sell about R$ 159,789.63 in the 6 week fowards
# Store 1078 are going to sell about R$ 218,099.64 in the 6 week fowards
# Store 1079 are going to sell about R$ 213,849.27 in the 6 week fowards
# Store 1080 are going to sell about R$ 224,436.40 in the 6 week fowards
# Store 1083 are going to sell about R$ 171,384.27 in the 6 week fowards
# Store 1084 are going to sell about R$ 202,915.24 in the 6 week fowards
# Store 1086 are going to sell about R$ 184,087.11 in the 6 week fowards
# Store 1087 are going to sell about R$ 219,846.86 in the 6 week fowards
# Store 1088 are going to sell about R$ 169,972.53 in the 6 week fowards
# Store 1089 are going to sell about R$ 245,228.85 in the 6 week fowards
# Store 1091 are going to sell about R$ 224,753.52 in the 6 week fowards
# Store 1092 are going to sell about R$ 227,300.71 in the 6 week fowards
# Store 1094 are going to sell about R$ 188,847.31 in the 6 week fowards
# Store 1096 are going to sell about R$ 192,478.64 in the 6 week fowards
# Store 1097 are going to sell about R$ 277,356.96 in the 6 week fowards
# Store 1099 are going to sell about R$ 197,676.77 in the 6 week fowards
# Store 1100 are going to sell about R$ 208,927.56 in the 6 week fowards
# Store 1101 are going to sell about R$ 228,942.44 in the 6 week fowards
# Store 1102 are going to sell about R$ 194,475.89 in the 6 week fowards
# Store 1103 are going to sell about R$ 164,239.78 in the 6 week fowards
# Store 1104 are going to sell about R$ 174,036.15 in the 6 week fowards
# Store 1105 are going to sell about R$ 170,001.52 in the 6 week fowards
# Store 1106 are going to sell about R$ 173,371.92 in the 6 week fowards
# Store 1107 are going to sell about R$ 181,699.50 in the 6 week fowards
# Store 1109 are going to sell about R$ 173,805.47 in the 6 week fowards
# Store 1111 are going to sell about R$ 173,404.86 in the 6 week fowards
# Store 1112 are going to sell about R$ 228,735.38 in the 6 week fowards
# Store 1113 are going to sell about R$ 220,798.84 in the 6 week fowards
# Store 1114 are going to sell about R$ 445,267.56 in the 6 week fowards
# Store 1115 are going to sell about R$ 196,293.13 in the 6 week fowards

# %%
sns.scatterplot(df2_result['store'], df2_result['prediction'])
# Out:
# <AxesSubplot:xlabel='store', ylabel='prediction'>
